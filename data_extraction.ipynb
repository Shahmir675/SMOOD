# %%
import psycopg2
import time
import pytz
import threading
import os
import datetime
import pandas as pd
from finvizfinance.quote import finvizfinance
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
def get_connection():
    try:
        connection = psycopg2.connect(
            dbname=os.getenv('DB_NAME'),
            user=os.getenv('DB_USER'),
            password=os.getenv('DB_PASSWORD'),
            host=os.getenv('DB_HOST'),
            options='-c statement_timeout=1020000'
        )

    except psycopg2.OperationalError as e:
        print(f'Error: {e}')
        return None

    else:
        print('Connected Established!')
        return connection

# %%
conn = get_connection()
cursor = conn.cursor()
# Out:
# Connected Established!

# %%
query = '''
SELECT Ticker FROM Stocks
'''

cursor.execute(query)
tickers = cursor.fetchall()
tickers = [ticker[0] for ticker in tickers]

# %%
news_dfs = {}

def get_news(ticker):
    print(f'Fetching headlines for {ticker}...')
    stock = finvizfinance(ticker)
    news_df = stock.ticker_news()
    return news_df 

def fetch_headlines(ticker):
    try:
        news_dfs[ticker] = get_news(ticker)
    except Exception as e:
        print(f"Error fetching headlines for {ticker}: {e}")
        fetch_headlines(ticker)

with ThreadPoolExecutor(max_workers=2) as executor:
    for i, ticker in enumerate(tickers):
        executor.submit(fetch_headlines, ticker)

# %store news_dfs

# %%
current_time = datetime.datetime.now(pytz.timezone('US/Eastern'))
et_now = current_time.replace(second=0, microsecond=0).replace(tzinfo=None)

# %%
def convert_to_ET(dt):
    eastern = pytz.timezone('US/Eastern')
    return dt.astimezone(eastern)

def extract_headlines_within_one_day(df, current_time):
    one_day_ago = current_time - pd.Timedelta(days=1)
    return df[df['Date'] >= one_day_ago]

def extract_headlines_within_one_week(df, current_time):
    one_week_ago = current_time - pd.Timedelta(weeks=1)
    return df[df['Date'] >= one_week_ago]

def extract_headlines_within_one_month(df, current_time):
    one_month_ago = current_time - pd.Timedelta(days=30)
    return df[df['Date'] >= one_month_ago]

def extract_headlines_within_timeframes(dictionary_of_dataframes):
    current_time_ET = convert_to_ET(datetime.datetime.now())
    current_time_ET = current_time_ET.replace(second=0, microsecond=0).replace(tzinfo=None)

    headlines_within_timeframes = {}

    for stock, df in dictionary_of_dataframes.items():
        daily_headlines = extract_headlines_within_one_day(df, current_time_ET)
        weekly_headlines = extract_headlines_within_one_week(df, current_time_ET)
        monthly_headlines = extract_headlines_within_one_month(df, current_time_ET)
        
        headlines_within_timeframes[stock] = {
            'Daily': daily_headlines,
            'Weekly': weekly_headlines,
            'Monthly': monthly_headlines
        }
    
    return headlines_within_timeframes

df = extract_headlines_within_timeframes(news_dfs)

# %store df

# %%
# %store -r df news_dfs

# %%
for ticker, period_data in df.items():
    for period, dataframe in period_data.items():

        if period == 'Daily':
            dataframe['is_daily'] = True
            dataframe['is_weekly'] = True
            dataframe['is_monthly'] = True

        elif period == 'Weekly':
            dataframe['is_daily'] = False
            dataframe['is_weekly'] = True
            dataframe['is_monthly'] = True

        elif period == 'Monthly':
            dataframe['is_daily'] = False
            dataframe['is_weekly'] = False
            dataframe['is_monthly'] = True

        desired_columns_order = ['Date', 'Title', 'Link','is_daily', 'is_weekly', 'is_monthly']
        dataframe = dataframe[desired_columns_order]

# %%
import pandas as pd

dfs = []

for ticker, data in df.items():
    dataframe['Ticker'] = ticker
    dataframe['Period'] = period

    dfs.append(dataframe)

merged_df = pd.concat(dfs, ignore_index=True)

filtered_df = merged_df.drop_duplicates(subset=['Ticker', 'Title'])

# %%
filtered_df['Date'] = filtered_df['Date'].astype(str)

filtered_df['is_daily'] = filtered_df['is_daily'].astype(str).str.lower()
filtered_df['is_weekly'] = filtered_df['is_weekly'].astype(str).str.lower()
filtered_df['is_monthly'] = filtered_df['is_monthly'].astype(str).str.lower()

values = [tuple(row) for row in filtered_df[['Date', 'Ticker', 'Title', 'is_daily', 'is_weekly', 'is_monthly']].values]
# Out:
# /tmp/ipykernel_17759/4103925058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Date'] = filtered_df['Date'].astype(str)
# /tmp/ipykernel_17759/4103925058.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['is_daily'] = filtered_df['is_daily'].astype(str).str.lower()
# /tmp/ipykernel_17759/4103925058.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['is_weekly'] = filtered_df['is_weekly'].astype(str).str.lower()
# /tmp/ipykernel_17759/4103925058.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['is_monthly'] = filtered_df['is_monthly'].astype(str).str.lower()

# %%
def insert_rows(values):
    conn = get_connection()
    cur = conn.cursor()

    cur.execute('DELETE FROM headlines')
    conn.commit()

    query = '''
    INSERT INTO headlines (publication_timestamp, ticker, headline, is_daily, is_weekly, is_monthly)
    VALUES (%s, %s, %s, %s, %s, %s)
    '''

    for value in values:
        cur.execute(query, value)
        conn.commit()
        print(value)

    cur.close()
    conn.close()

num_threads = 16  
chunk_size = len(values) // num_threads + 1
value_chunks = [values[i:i+chunk_size] for i in range(0, len(values), chunk_size)]

with ThreadPoolExecutor(max_workers=num_threads) as executor:
    futures = [executor.submit(insert_rows, chunk) for chunk in value_chunks]
    for future in futures:
        future.result()
# Out:
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# Connected Established!
# ('2024-02-13 16:45:00', 'MAR', 'UPDATE 1-The new normal: travel companies temper expectations for 2024', 'false', 'true', 'true')
# ('2024-02-14 16:59:00', 'AWK', 'American Water Works Co Inc (AWK) Reports Solid 2023 Earnings and Raises 2024 EPS Guidance', 'false', 'true', 'true')
# ('2024-02-15 14:36:00', 'CMG', 'Giving Uber Its Due', 'false', 'true', 'true')
# ('2024-02-07 09:14:00', 'MRNA', 'Moderna Chief Executive Officer Stéphane Bancel Elected to National Academy of Engineering', 'false', 'false', 'true')
# ('2024-02-05 15:33:00', 'MSCI', 'EMERGING MARKETS-Latam currencies edge lower as traders pare Fed rate cut bets, Argentina in focus', 'false', 'false', 'true')
# ('2024-02-16 02:10:00', 'AMAT', 'Applied Materials sees faster recovery in semiconductors, to benefit from HBM and GAA equipment', 'false', 'true', 'true')
# ('2024-02-06 06:01:00', 'CRM', 'Navigating Market Uncertainty: Intrinsic Value of Salesforce Inc', 'false', 'false', 'true')
# ('2024-01-23 08:30:00', 'BMY', 'Bristol Myers Squibb Completes Acquisition of Mirati Therapeutics, Strengthening and Diversifying Oncology Portfolio', 'false', 'false', 'true')
# ('2024-02-08 09:00:00', 'LRCX', 'Lam Research Corporation (LRCX) is Attracting Investor Attention: Here is What You Should Know', 'false', 'false', 'true')
# ('2024-02-17 11:49:00', 'JPM', '5 Best Breakout Stocks To Buy Right Now', 'false', 'true', 'true')
# ('2024-02-11 13:06:00', 'ABT', "Abbott Laboratories Is the Latest Company to Get Involved in the Weight Loss Market. Here's How.", 'false', 'false', 'true')
# ('2024-02-14 09:03:00', 'K', 'Full bellies, fuller hearts: Kellanova and Albertsons Companies Foundation show love to the communities they serve', 'false', 'true', 'true')
# ('2024-01-29 09:16:00', 'MTCH', 'Insights Into Match Group (MTCH) Q4: Wall Street Projections for Key Metrics', 'false', 'false', 'true')
# ('2024-02-12 05:02:00', 'ENPH', 'Down 46% to 65%, 2 Stocks to Buy Right Now', 'false', 'false', 'true')
# ('2024-02-20 17:31:00', 'MSFT', 'Microsoft to expand its AI infrastructure in Spain with $2.1 billion investment', 'true', 'true', 'true')
# ('2024-01-25 06:00:00', 'DOW', 'Dow reports fourth quarter 2023 results', 'false', 'false', 'true')
# ('2024-02-13 14:45:00', 'MAR', 'The new normal: travel companies temper expectations for 2024', 'false', 'true', 'true')
# ('2024-02-14 16:57:00', 'AWK', 'American Water Works: Q4 Earnings Snapshot', 'false', 'true', 'true')
# ('2024-02-15 10:35:00', 'CMG', 'Shake Shack promotes Michael Kark to expanded global licensing role', 'false', 'true', 'true')
# ('2024-02-07 09:14:00', 'MRNA', 'Moderna Chief Executive Officer Stephane Bancel Elected to National Academy of Engineering', 'false', 'false', 'true')
# ('2024-02-05 15:08:00', 'MSCI', 'Chinas Steps to Aid Stocks Wont Fix the Problems. Why Theyre a Positive Sign.', 'false', 'false', 'true')
# ('2024-02-15 21:14:00', 'AMAT', 'Applied Materials reiterates commitment to developing chipmaking ecosystem in India', 'false', 'true', 'true')
# ('2024-02-05 17:45:00', 'CRM', 'Salesforce.com (CRM) Gains As Market Dips: What You Should Know', 'false', 'false', 'true')
# ('2024-01-22 17:05:00', 'BMY', 'Eight-Year Data for Opdivo (nivolumab) Plus Yervoy (ipilimumab) Continue to Demonstrate Longest Survival Benefit vs. Sunitinib Reported in Patients with Previously Untreated Advanced or Metastatic Renal Cell Carcinoma', 'false', 'false', 'true')
# ('2024-02-17 00:07:00', 'JPM', 'Decoding JPMorgan Chase & Co (JPM): A Strategic SWOT Insight', 'false', 'true', 'true')
# ('2024-02-05 09:40:00', 'LRCX', 'Is Lam Research (LRCX) Outperforming Other Computer and Technology Stocks This Year?', 'false', 'false', 'true')
# ('2024-02-11 06:51:00', 'ABT', '3 Groundbreaking Healthcare Stocks to Buy for Robust Gains', 'false', 'false', 'true')
# ('2024-02-13 15:19:00', 'K', 'WK Kellogg Posted Declining Sales. Why the Cereal Stock Still Jumped 9%.', 'false', 'true', 'true')
# ('2024-01-29 02:00:00', 'MTCH', 'Match Group (MTCH) Q4 Earnings Report Preview: What To Look For', 'false', 'false', 'true')
# ('2024-02-10 00:26:00', 'ENPH', 'Decoding Enphase Energy Inc (ENPH): A Strategic SWOT Insight', 'false', 'false', 'true')
# ('2024-02-20 11:30:00', 'MSFT', "Microsoft Responds To New York Times Lawsuit With AI-startup Claiming, 'No News Organization Has A Monopoly'", 'true', 'true', 'true')
# ('2024-01-23 08:16:00', 'DOW', "Dow (DOW) Gears Up for Q4 Earnings: What's in the Offing?", 'false', 'false', 'true')
# ('2024-02-13 14:30:00', 'MAR', 'S&P 500 Drops After Inflation Data', 'false', 'true', 'true')
# ('2024-02-14 16:31:00', 'AWK', 'American Water Reports Strong 2023 Results; Affirms Long-Term Growth Targets; Increases 2024 EPS Guidance Resulting From Note Restructuring', 'false', 'true', 'true')
# ('2024-02-15 01:46:00', 'CMG', "Bill Ackman's Pershing Square Cuts Lowe's Stake by Over 80%", 'false', 'true', 'true')
# ('2024-02-05 06:52:00', 'MRNA', 'UPDATE 1-Moderna-backed Metagenomi targets up to $638 mln valuation for US IPO', 'false', 'false', 'true')
# ('2024-02-05 03:38:00', 'MSCI', "Here're Emeth Value Capital's Views on Driven Brands Holdings (DRVN)", 'false', 'false', 'true')
# ('2024-02-15 20:00:00', 'AMAT', 'Applied Materials (AMAT) Q1 2024 Earnings Call Transcript', 'false', 'true', 'true')
# ('2024-01-22 17:00:00', 'BMY', 'Opdivo (nivolumab) in Combination with CABOMETYX (cabozantinib) Demonstrates Long-Term Survival Benefits After Four Years of Follow-Up in the CheckMate -9ER Trial in First-Line Advanced Renal Cell Carcinoma', 'false', 'false', 'true')
# ('2024-02-04 07:45:00', 'CRM', 'S&P 500 Bull Market: 3 Phenomenal Stocks to Buy Now', 'false', 'false', 'true')
# ('2024-02-04 07:15:00', 'LRCX', 'Up 75% in a Year, This Artificial Intelligence (AI) Chip Stock Could Skyrocket Another 50%', 'false', 'false', 'true')
# ('2024-02-16 18:31:00', 'JPM', 'UPDATE 1-JPMorgan to pay about $350 mln penalty over trade reporting gaps', 'false', 'true', 'true')
# ('2024-02-10 08:30:00', 'ABT', '30 Most Valuable Drug Companies in 2024', 'false', 'false', 'true')
# ('2024-02-13 09:17:00', 'K', 'WK Kellogg raises annual profit forecast as demand stays steady amid price hikes', 'false', 'true', 'true')
# ('2024-02-09 21:02:00', 'ENPH', "Jim Cramer sheds light on Enphase Energy's quarterly results", 'false', 'false', 'true')('2024-01-24 13:51:00', 'MTCH', 'Hot Picks: 7 Stocks Wall Street Expects to Double in 2024', 'false', 'false', 'true')
#
# ('2024-02-20 11:00:00', 'MSFT', "Is OpenAI's Sora a Threat to This AI Behemoth? Should Investors Buy the Dip?", 'true', 'true', 'true')
# ('2024-01-22 14:15:00', 'DOW', 'Attracting & Developing Diverse Talent at Dow', 'false', 'false', 'true')
# ('2024-02-13 14:16:00', 'MAR', "Marriott International's U.S. Business Slows After Post-Pandemic Peak", 'false', 'true', 'true')
# ('2024-02-13 13:39:00', 'AWK', 'Pennsylvania American Water Awards $36K+ in Inclusion, Diversity and Equity Funding to 13 Organizations', 'false', 'true', 'true')
# ('2024-02-14 09:30:00', 'CMG', 'Is It Time to Buy Chipotle Stock Hand Over Fist in 2024? The Answer Is Yes, but Only if You Believe 1 Thing.', 'false', 'true', 'true')
# ('2024-02-05 06:17:00', 'MRNA', 'Moderna-backed Metagenomi targets up to $638 mln valuation for US IPO', 'false', 'false', 'true')
# ('2024-02-05 03:29:00', 'MSCI', "Emeth Value Capital's Q4 2023 Investor Letter", 'false', 'false', 'true')
# ('2024-02-15 18:00:00', 'AMAT', 'Compared to Estimates, Applied Materials (AMAT) Q1 Earnings: A Look at Key Metrics', 'false', 'true', 'true')
# ('2024-02-17 13:29:00', 'CI', '14 Best Medical Stocks To Invest In According to Hedge Funds', 'false', 'true', 'true')
# ('2024-01-31 16:29:00', 'CRM', 'Light Street Capital Returned 46% in 2023: Top 15 Picks', 'false', 'false', 'true')
# ('2024-02-03 07:20:00', 'LRCX', "1 Chip Manufacturing Equipment Stock I'm Buying Right Now", 'false', 'false', 'true')
# ('2024-02-16 17:01:00', 'JPM', 'JPMorgan to pay about $350 million penalty over trade reporting gaps', 'false', 'true', 'true')
# ('2024-02-09 09:00:00', 'ABT', 'Abbott Laboratories (ABT) Is a Trending Stock: Facts to Know Before Betting on It', 'false', 'false', 'true')
# ('2024-02-13 08:43:00', 'K', 'WK Kellogg Swings To Profit In Q4; Guides Net Sales Above Estimates', 'false', 'true', 'true')
# ('2024-02-09 21:02:00', 'ENPH', 'Enphase Energy is one of the higher quality operators in the space, says Jim Cramer', 'false', 'false', 'true')
# ('2024-01-23 10:00:00', 'MTCH', 'Match Group (MTCH) Reports Next Week: Wall Street Expects Earnings Growth', 'false', 'false', 'true')
# ('2024-01-22 13:37:00', 'DOW', 'What Analyst Projections for Key Metrics Reveal About Dow Inc. (DOW) Q4 Earnings', 'false', 'false', 'true')
# ('2024-02-20 09:28:00', 'MSFT', 'Apple Could Face EU Fine Over Spotify Complaint. Why Its a Big Deal.', 'true', 'true', 'true')
# ('2024-02-13 13:36:00', 'MAR', 'Marriott (MAR) Q4 Earnings Surpass Estimates, Revenues Miss', 'false', 'true', 'true')
# ('2024-02-12 14:17:00', 'AWK', 'California American Water Appeals Ruling on LAFCO Decision', 'false', 'false', 'true')
# ('2024-02-14 02:02:00', 'CMG', 'Earnings To Watch: Shake Shack (SHAK) Reports Q4 Results Tomorrow', 'false', 'true', 'true')
# ('2024-02-01 16:17:00', 'MRNA', 'Pfizer Surprises With Profit But Revolutionizing Cancer Treatment Is Its Best Chance Of Getting Back In The Saddle', 'false', 'false', 'true')
# ('2024-02-04 07:50:00', 'MSCI', "Companies test out different ways to talk about ESG without saying 'ESG'", 'false', 'false', 'true')
# ('2024-02-15 17:15:00', 'AMAT', 'Applied Materials (AMAT) Q1 Earnings and Revenues Top Estimates', 'false', 'true', 'true')
# ('2024-01-30 17:45:00', 'CRM', 'Salesforce.com (CRM) Stock Moves -0.05%: What You Should Know', 'false', 'false', 'true')
# ('2024-02-15 06:00:00', 'CI', 'The Cigna Group Announces $3.2 Billion Accelerated Stock Repurchase', 'false', 'true', 'true')
# ('2024-02-16 16:51:00', 'JPM', 'JPMorgan to pay about $350 mln in fine for trade reporting failures', 'false', 'true', 'true')
# ('2024-01-30 09:30:00', 'LRCX', 'Lam Research (LRCX) Reports Q2 Earnings: What Key Metrics Have to Say', 'false', 'false', 'true')
# ('2024-02-13 08:38:00', 'K', 'Eggo is helping foster Black agriculture through partnership with National Black Growers Council', 'false', 'true', 'true')
# ('2024-02-09 06:45:00', 'ABT', 'These 2 Stocks Are Trying to Ride the Ozempic Bandwagon: Are They Buys?', 'false', 'false', 'true')
# ('2024-02-09 17:07:00', 'ENPH', 'Why Enphase Energy Stock Jumped 22.1% This Week', 'false', 'false', 'true')
# ('2024-02-16 11:25:00', 'ODFL', 'Old Dominion Freight Line Declares Two-for-One Stock Split', 'false', 'true', 'true')
# ('2024-01-22 03:35:00', 'MTCH', 'Spotting Winners: Udemy (NASDAQ:UDMY) And Consumer Subscription Stocks In Q3', 'false', 'false', 'true')
# ('2024-02-20 07:30:00', 'MSFT', '"Magnificent Seven" Stock Shake-Up -- 3 Business Stats You Need to See Right Now', 'true', 'true', 'true')
# ('2024-02-13 13:25:00', 'MAR', 'Marriott Earnings Beats Estimates. Why the Stock Is Falling Anyway.', 'false', 'true', 'true')
# ('2024-02-09 10:04:00', 'AWK', 'American Water (AWK) to Post Q4 Earnings: What Awaits?', 'false', 'false', 'true')
# ('2024-02-13 09:43:00', 'CMG', '11 Stocks That May Be Splitting Soon', 'false', 'true', 'true')
# ('2024-02-01 07:00:00', 'MRNA', 'Moderna to Report Fourth Quarter and Full Year 2023 Financial Results on Thursday, February 22, 2024', 'false', 'false', 'true')
# ('2024-02-01 10:58:00', 'MSCI', 'MSCI Inc. (NYSE:MSCI) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-02-15 17:13:00', 'AMAT', 'Applied Materials Stock Jumps on Strong Earnings Beat', 'false', 'true', 'true')
# ('2024-01-30 08:50:00', 'CRM', 'The S&P 500 Just Hit Another All-Time High: 3 Growth Stocks to Buy Hand Over Fist Now', 'false', 'false', 'true')
# ('2024-02-15 04:51:00', 'CI', 'HelloFresh to offer discounted meal kits to Cigna Healthcare members', 'false', 'true', 'true')
# ('2024-02-16 16:31:00', 'JPM', 'JPMorgan Chase Files Form 10-K for the Fiscal Year Ended December 31, 2023', 'false', 'true', 'true')
# ('2024-01-30 02:01:00', 'LRCX', 'Earnings To Watch: Kulicke and Soffa (KLIC) Reports Q1 Results Tomorrow', 'false', 'false', 'true')
# ('2024-02-13 08:32:00', 'K', 'WK Kellogg Co Reports Robust Full Year 2023 Results and Uplifts 2024 EBITDA Outlook', 'false', 'true', 'true')
# ('2024-02-08 08:30:00', 'ABT', 'New Study Shows Mixed Reality Technology for Blood Donation From Abbott and Blood Centers of America Helps Ease Stress, Encourages People To Donate Again', 'false', 'false', 'true')
# ('2024-02-09 09:00:00', 'ENPH', 'Enphase Energy Stock Is Up, but the Future Is Still Cloudy', 'false', 'false', 'true')
# ('2024-02-14 13:35:00', 'ODFL', '5 Most Valuable Logistics Companies in the World in 2024', 'false', 'true', 'true')
# ('2024-02-09 17:29:00', 'WYNN', 'Why Wynn Resorts Stock Jumped 8.5% This Week', 'false', 'false', 'true')
# ('2024-02-20 07:16:00', 'MSFT', 'Nintendo Stock Drops, and Other Tech News Today', 'true', 'true', 'true')
# ('2024-02-13 11:37:00', 'MAR', 'Analyst Report: Marriott International, Inc.', 'false', 'true', 'true')
# ('2024-02-08 17:40:00', 'AWK', 'American Water Charitable Foundation Invests More Than a Quarter Million Dollars in California and Hawaii', 'false', 'false', 'true')
# ('2024-02-12 11:00:00', 'CMG', 'After a Magnificent Quarter, Chipotle Proves Again Why It Should Be a Top Warren Buffett Stock', 'false', 'false', 'true')
# ('2024-01-31 17:45:00', 'MRNA', 'Moderna (MRNA) Stock Moves -1.39%: What You Should Know', 'false', 'false', 'true')
# ('2024-02-15 17:09:00', 'AMAT', 'Applied Materials Stock Surges After Beat-And-Raise Earnings Report', 'false', 'true', 'true')
# ('2024-01-31 01:16:00', 'MSCI', 'Q4 2023 MSCI Inc Earnings Call', 'false', 'false', 'true')
# ('2024-01-30 08:43:00', 'CRM', 'TSM, CRM, GOOGL: The Top 3 Stocks to Buy in 2024', 'false', 'false', 'true')
# ('2024-02-14 13:41:00', 'CI', 'Top 5 Most Valuable Insurance Companies in the US', 'false', 'true', 'true')
# ('2024-01-29 11:32:00', 'LRCX', 'Nasdaq 100s Hidden Gems: 7 Tech Stock Bargains Ready to Boom', 'false', 'false', 'true')
# ('2024-02-16 14:02:00', 'JPM', 'JPMorgan Beats Private Credit in $2.5 Billion Debt Deal for SoftBank-backed Cohesity', 'false', 'true', 'true')
# ('2024-02-09 11:35:00', 'K', 'Kellogg Company (NYSE:K) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-02-07 11:11:00', 'ABT', 'Abbott Laboratories Stock Getting Closer To Key Technical Benchmark', 'false', 'false', 'true')
# ('2024-02-08 09:38:00', 'ODFL', 'Analyst Report: Old Dominion Freight Line, Inc.', 'false', 'false', 'true')
# ('2024-02-09 04:51:00', 'ENPH', 'Enphase Stock Just Surged, but Solar Is a Mess: What You Should Know Before Buying', 'false', 'false', 'true')
# ('2024-02-09 15:10:00', 'WYNN', 'Record Super Bowl Bets Up the Ante for Online Gambling Stocks', 'false', 'false', 'true')
# ('2024-02-20 06:25:00', 'MSFT', '15 Worst Countries to Live in as an Expat', 'true', 'true', 'true')
# ('2024-02-13 10:41:00', 'MAR', 'Marriott: Strong 2023 With Record Luxury Hotels Deals', 'false', 'true', 'true')
# ('2024-02-08 11:30:00', 'AWK', 'American Water Named One of Americas Most JUST Companies by JUST Capital and CNBC', 'false', 'false', 'true')
# ('2024-02-12 08:26:00', 'CMG', 'Jim Cramers 11 Latest Stock Picks', 'false', 'false', 'true')
# ('2024-01-31 17:45:00', 'MRNA', "Moderna Named to Fortune's List of World's Most Admired Companies", 'false', 'false', 'true')
# ('2024-01-30 14:45:00', 'MSCI', 'MSCI (MSCI) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-02-15 16:44:00', 'AMAT', 'Applied Materials Jumps After Forecast Shows Chip Rebound', 'false', 'true', 'true')
# ('2024-01-30 07:12:00', 'CRM', '3 Disruptive AI Stocks That Could Dominate the Market by 2027', 'false', 'false', 'true')
# ('2024-02-13 07:00:00', 'CI', 'Cigna Healthcare and HelloFresh Team Up To Expand Access to Affordable, Healthy Meal Choices', 'false', 'true', 'true')
# ('2024-01-29 03:22:00', 'LRCX', '10 Best Performing Growth Stocks in January 2024', 'false', 'false', 'true')
# ('2024-02-16 11:32:00', 'JPM', "David Solomon's pay rises to $31 million after most challenging year as Goldman CEO", 'false', 'true', 'true')
# ('2024-02-09 09:41:00', 'K', 'Kellanova to close US frozen foods plant, UK factory', 'false', 'false', 'true')
# ('2024-02-07 06:01:00', 'ABT', 'Invest with Confidence: Intrinsic Value Unveiled of Abbott Laboratories', 'false', 'false', 'true')
# ('2024-02-08 08:23:00', 'ODFL', 'Weak Freight Market Reflected on Old Dominion Freight Lines (ODFL) Performance in Q4', 'false', 'false', 'true')
# ('2024-02-07 16:33:00', 'ENPH', 'These Stocks Moved the Most Today: Snap, Alibaba, Enphase, Sonos, VF Corp., Ford, Emerson, and More', 'false', 'false', 'true')
# ('2024-02-09 11:00:00', 'WYNN', 'Las Vegas Casinos Are Great, but the Growth Is in Asia', 'false', 'false', 'true')
# ('2024-02-20 06:00:00', 'MSFT', "The Art of Valuation: Discovering Microsoft Corp's Intrinsic Value", 'true', 'true', 'true')
# ('2024-02-13 09:52:00', 'MAR', 'Stocks to Watch Tuesday: Arm, Shopify, JetBlue', 'false', 'true', 'true')
# ('2024-02-08 11:00:00', 'AWK', 'Illinois American Water President Rebecca Losli Named Chairperson of the Illinois Utilities Business Diversity Council', 'false', 'false', 'true')
# ('2024-02-11 10:00:00', 'CMG', "Chipotle Stock Just Jumped 8% in 24 Hours. Here's Why Investors Are Buying This Stock Hand Over Fist.", 'false', 'false', 'true')
# ('2024-01-30 11:02:00', 'MRNA', 'Baillie Gifford Bolsters Stake in Moderna Inc', 'false', 'false', 'true')
# ('2024-01-30 13:27:00', 'MSCI', 'MSCI Stock Is the S&P 500s Top Performer on Tuesday', 'false', 'false', 'true')('2024-01-29 16:15:00', 'CRM', "LeddarTech's Board of Directors Appoints Sylvie Veilleux and Lizabeth Ardisana", 'false', 'false', 'true')
#
# ('2024-02-11 08:00:00', 'CI', 'Your Medicare Plan Might Not Include as Many Freebies Next Year', 'false', 'false', 'true')
# ('2024-02-15 16:33:00', 'AMAT', 'Applied Materials Inc (AMAT) Reports Stable Revenue and Increased Earnings in Q1 2024', 'false', 'true', 'true')
# ('2024-01-29 02:01:00', 'LRCX', 'Teradyne (TER) Q4 Earnings Report Preview: What To Look For', 'false', 'false', 'true')
# ('2024-02-16 07:04:00', 'JPM', 'JPMorgan appoints Rachid Alaoui head of global equities - memo', 'false', 'true', 'true')
# ('2024-02-09 03:47:00', 'K', 'Heard on the Street Recap: The Earnings Beats Continue and Morale Has Improved', 'false', 'false', 'true')
# ('2024-02-07 05:17:00', 'ABT', 'Want to Get Richer? Here Are the 3 Best Stocks to Buy Now and Hold Forever', 'false', 'false', 'true')
# ('2024-02-07 16:02:00', 'ENPH', 'This Clean-Energy Stock Just Missed Earnings And Gave A Cloudy Outlook. Shares Jumped 17%.', 'false', 'false', 'true')
# ('2024-02-01 11:57:00', 'ODFL', 'Old Dominion Freight Line, Inc. (NASDAQ:ODFL) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-02-08 22:07:00', 'WYNN', "Nevada high court dismisses casino mogul Steve Wynn's defamation suit against The Associated Press", 'false', 'false', 'true')
# ('2024-02-13 09:30:00', 'MAR', 'Marriott (MAR) Reports Q4 Earnings: What Key Metrics Have to Say', 'false', 'true', 'true')
# ('2024-02-20 05:05:00', 'MSFT', '2 "Magnificent Seven" Stocks That Are AI Buys in 2024', 'true', 'true', 'true')
# ('2024-02-07 10:00:00', 'AWK', 'American Water Works (AWK) Earnings Expected to Grow: Should You Buy?', 'false', 'false', 'true')
# ('2024-02-11 04:50:00', 'CMG', '3 Incredible Stocks That Could Supercharge Your Portfolio in 2024', 'false', 'false', 'true')
# ('2024-01-27 05:05:00', 'MRNA', 'My Top-5 AI Growth Stocks to Buy Hand Over Fist for 2024', 'false', 'false', 'true')
# ('2024-01-30 13:13:00', 'MSCI', 'MSCI Stock Is the S&P 500s Top Performer on Tuesday. Demand Drives an Earnings Beat.', 'false', 'false', 'true')
# ('2024-01-29 12:56:00', 'CRM', '15 Best Stocks To Buy According to Billionaires', 'false', 'false', 'true')
# ('2024-02-09 09:42:00', 'CI', 'Stocks Win and Credit Loses as Companies Cater to Shareholders', 'false', 'false', 'true')
# ('2024-02-15 16:23:00', 'AMAT', 'Applied Materials: Fiscal Q1 Earnings Snapshot', 'false', 'true', 'true')
# ('2024-01-28 08:33:00', 'LRCX', 'Artificial Intelligence (AI) Just Pushed This Chip Stock to New All-Time Highs, and Should Push It Even Higher', 'false', 'false', 'true')
# ('2024-02-15 20:48:00', 'JPM', 'Alleged fraudster Charlie Javice loses bid to have JPMorgan pay for counterclaims as legal battle continues', 'false', 'true', 'true')
# ('2024-02-09 00:06:00', 'K', 'Q4 2023 Kellanova Earnings Call', 'false', 'false', 'true')
# ('2024-02-06 08:30:00', 'ABT', 'Decade of Impact: Transforming Care in Tanzania', 'false', 'false', 'true')
# ('2024-02-07 13:33:00', 'ENPH', 'Enphase Energy surges on expectations for demand rebounds', 'false', 'false', 'true')
# ('2024-02-01 04:21:00', 'ODFL', 'Q4 2023 Old Dominion Freight Line Inc Earnings Call', 'false', 'false', 'true')
# ('2024-02-13 08:20:00', 'MAR', 'Marriott International (MAR) Tops Q4 Earnings Estimates', 'false', 'true', 'true')
# ('2024-02-08 17:08:00', 'WYNN', 'These Stocks Moved the Most Today: Arm, Disney, PayPal, Confluent, Monolithic Power, Ralph Lauren, and More', 'false', 'false', 'true')
# ('2024-02-20 04:40:00', 'MSFT', 'The "Dean of Valuation" Is Selling Nvidia Stock Hand Over Fist. Should You?', 'true', 'true', 'true')
# ('2024-02-06 11:00:00', 'AWK', 'American Water Shares Convenient Ways for Customers to Pay their Water Bill', 'false', 'false', 'true')
# ('2024-02-11 02:15:00', 'CMG', "Chipotle Is Up Over 120-Fold Since Its IPO. Here's Why It Will Probably Keep Making Investors Richer.", 'false', 'false', 'true')
# ('2024-01-26 05:50:00', 'MRNA', "1 Growth Stock Down 79% That's a Screaming Buy Right Now, According to Several Wall Street Analysts", 'false', 'false', 'true')
# ('2024-01-30 11:13:00', 'MSCI', "Cramer's Stop Trading: MSCI Inc.", 'false', 'false', 'true')
# ('2024-01-29 09:45:00', 'CRM', 'Is Hubspot Stock the Next Salesforce in the Making?', 'false', 'false', 'true')
# ('2024-02-08 18:09:00', 'CI', '30 Largest Companies in the World by Revenue', 'false', 'false', 'true')
# ('2024-02-15 16:06:00', 'AMAT', 'UPDATE 1-Applied Materials forecasts quarterly revenue above estimates', 'false', 'true', 'true')
# ('2024-01-26 23:16:00', 'LRCX', 'AVUS ETF: Best of Both Worlds\xa0 Active and Passive Investing', 'false', 'false', 'true')
# ('2024-02-15 19:46:00', 'JPM', 'JPMorgan, First Citizens Lend $75M on Manhattan Resi Tower', 'false', 'true', 'true')
# ('2024-02-08 16:50:00', 'K', 'Lightspeed, Kellanova post quarterly beats: Trending Tickers', 'false', 'false', 'true')
# ('2024-02-13 07:00:00', 'MAR', 'MARRIOTT INTERNATIONAL REPORTS STRONG FOURTH QUARTER AND FULL YEAR 2023 RESULTS', 'false', 'true', 'true')
# ('2024-02-05 09:45:00', 'ABT', '2 Stocks to Buy Near Their 52-Week Highs', 'false', 'false', 'true')
# ('2024-02-07 13:22:00', 'ENPH', 'These Stocks Are Moving the Most Today: Snap, Alibaba, Enphase, Sonos, VF Corp., Ford, Emerson, and More', 'false', 'false', 'true')
# ('2024-01-31 13:05:00', 'ODFL', 'Old Dominion readies for eventual turnaround', 'false', 'false', 'true')
# ('2024-02-08 17:01:00', 'WYNN', 'Wynn Resorts Announces Commencement of Tender Offer for Cash by Wynn Las Vegas, LLC for its 5.500% Senior Notes due 2025', 'false', 'false', 'true')
# ('2024-02-18 16:48:00', 'MSFT', '16 Best Income Stocks To Buy According to Analysts', 'false', 'true', 'true')
# ('2024-02-05 11:00:00', 'AWK', 'American Water Charitable Foundation Launches 2024 Water and Environment Grant Program', 'false', 'false', 'true')
# ('2024-02-10 14:34:00', 'CMG', 'Super Bowl LVIII: The top food and drink stocks in focus, from PepsiCo to Chipotle', 'false', 'false', 'true')
# ('2024-01-30 10:00:00', 'MSCI', 'MSCI (MSCI) Q4 Earnings: Taking a Look at Key Metrics Versus Estimates', 'false', 'false', 'true')('2024-01-26 02:19:00', 'MRNA', 'AI healthcare: Moderna CIO highlights transformative role at CES 2024', 'false', 'false', 'true')
#
# ('2024-02-08 11:50:00', 'CI', 'CEO Bertolini: 2024 is the year Oscar will be profitable', 'false', 'false', 'true')
# ('2024-01-29 09:44:00', 'CRM', 'AIs path in 2024: Another year of growth instead of monetization', 'false', 'false', 'true')
# ('2024-02-15 16:06:00', 'AMAT', 'Applied Materials sees quarterly revenue above estimates on AI boom', 'false', 'true', 'true')
# ('2024-01-26 16:43:00', 'LRCX', 'Analyst Upgrades: 7 Stocks Predicted to Soar in Q1 2024', 'false', 'false', 'true')
# ('2024-02-15 16:25:00', 'JPM', 'JPMorgan Chase Declares Preferred Stock Dividends', 'false', 'true', 'true')
# ('2024-02-08 16:26:00', 'K', 'Analyst Report: Kellanova', 'false', 'false', 'true')
# ('2024-02-08 16:00:00', 'MAR', 'MARRIOTT INTERNATIONAL DECLARES QUARTERLY CASH DIVIDEND', 'false', 'false', 'true')
# ('2024-02-05 08:25:00', 'ABT', 'Abbott Launches New PROTALITY(TM) Brand To Support Adults on Their Weight Loss Journey', 'false', 'false', 'true')
# ('2024-01-31 12:56:00', 'ODFL', 'ODFL Reports Slight Revenue Bump to $1.5 Billion for Q4', 'false', 'false', 'true')
# ('2024-02-07 13:12:00', 'ENPH', 'Enphase Stock Is Soaring', 'false', 'false', 'true')
# ('2024-02-08 17:00:00', 'WYNN', 'Wynn Resorts Announces Pricing of Private Add-On Offering of $400 Million Aggregate Principal Amount of Wynn Resorts Finance 7.125% Senior Notes due 2031', 'false', 'false', 'true')
# ('2024-02-18 13:46:00', 'MSFT', '50 Funny Things To Ask Chatgpt and Googles AI Chatbot', 'false', 'true', 'true')
# ('2024-02-02 12:59:00', 'AWK', '3 Dividend Diamonds Offering Stability and Growth', 'false', 'false', 'true')
# ('2024-02-09 18:31:00', 'CMG', 'NYCB Stock Is Very Attractive, Says Piper Sandler', 'false', 'false', 'true')
# ('2024-01-25 13:37:00', 'MRNA', "Can Moderna's (MRNA) Launches Reduce COVID Sales Dependency?", 'false', 'false', 'true')
# ('2024-01-30 07:55:00', 'MSCI', 'MSCI (MSCI) Q4 Earnings and Revenues Top Estimates', 'false', 'false', 'true')
# ('2024-02-08 09:15:00', 'CI', 'Cigna Group (CI) Hits Fresh High: Is There Still Room to Run?', 'false', 'false', 'true')
# ('2024-01-29 09:00:00', 'CRM', 'Is Most-Watched Stock Salesforce Inc. (CRM) Worth Betting on Now?', 'false', 'false', 'true')
# ('2024-01-26 12:00:00', 'LRCX', 'What Makes Lam Research (LRCX) a Strong Momentum Stock: Buy Now?', 'false', 'false', 'true')
# ('2024-02-15 16:05:00', 'AMAT', 'Applied Materials (NASDAQ:AMAT) Surprises With Q1 Sales, Stock Soars', 'false', 'true', 'true')
# ('2024-02-15 14:01:00', 'JPM', 'No guarantee of rate cuts when inflation hits 2pc, warns Bank official', 'false', 'true', 'true')
# ('2024-02-08 15:24:00', 'K', 'Kellanova Plans Supply Chain Reorganizations', 'false', 'false', 'true')
# ('2024-02-08 09:15:00', 'MAR', 'Gear Up for Marriott (MAR) Q4 Earnings: Wall Street Estimates for Key Metrics', 'false', 'false', 'true')
# ('2024-02-04 08:20:00', 'ABT', '2 Healthcare Dividend Kings to Buy and Hold Forever', 'false', 'false', 'true')
# ('2024-02-07 12:58:00', 'ENPH', 'Top Stock Movers Now: Snap, Enphase Energy, VF, and More', 'false', 'false', 'true')
# ('2024-01-31 12:26:00', 'ODFL', 'Old Dominion (ODFL) Beats on Q4 Earnings, Hikes Dividend', 'false', 'false', 'true')
# ('2024-02-08 16:17:00', 'WYNN', 'Wynn Resorts Rallies On Q4 Earnings, Casino Revenue Spikes 152%', 'false', 'false', 'true')
# ('2024-02-18 13:18:00', 'MSFT', 'Top 15 Democratic Socialist Countries In Europe', 'false', 'true', 'true')
# ('2024-02-01 14:44:00', 'AWK', '3 Safe Haven Stocks to Weather Market Volatility', 'false', 'false', 'true')
# ('2024-02-09 14:44:00', 'CMG', "NRN editors discuss Chipotle's big numbers, the future of beef, and Valentine's Day promotions", 'false', 'false', 'true')
# ('2024-01-30 07:28:00', 'MSCI', 'MSCI quarterly profit rises on subscription strength', 'false', 'false', 'true')
# ('2024-01-25 09:55:00', 'MRNA', 'Jim Cramer is Recommending These 10 Stocks', 'false', 'false', 'true')
# ('2024-02-06 14:00:00', 'CI', "SEVENTH ANNUAL 'VINCENT COUNTRY SAFE ZONE ACTIVITY DAY' THEMED DREAM BIGGER, ACHIEVE GREATER HELD AT MATT KELLY ELEMENTARY DURING SUPER BOWL LVIII WEEK IN LAS VEGAS, NV", 'false', 'false', 'true')
# ('2024-01-27 05:29:00', 'CRM', '18 Best 52-Week Low Stocks To Buy Now', 'false', 'false', 'true')
# ('2024-01-26 09:15:00', 'LRCX', 'Lam Research Corporation (LRCX) Hits Fresh High: Is There Still Room to Run?', 'false', 'false', 'true')
# ('2024-02-15 16:03:00', 'AMAT', 'Applied Materials forecasts quarterly revenue above estimates', 'false', 'true', 'true')
# ('2024-02-15 13:26:00', 'JPM', "JPMorgan's Phil Camporeale: Prepare for a soft landing", 'false', 'true', 'true')
# ('2024-02-08 12:27:00', 'K', 'Stocks to Watch Thursday: Arm, Disney, PayPal', 'false', 'false', 'true')
# ('2024-02-08 09:00:00', 'MAR', 'Marriott International, Inc. (MAR) is Attracting Investor Attention: Here is What You Should Know', 'false', 'false', 'true')
# ('2024-01-31 10:06:00', 'ODFL', 'Old Dominion Freight Line Inc. Reports Modest Revenue Growth Amid Economic Softness', 'false', 'false', 'true')
# ('2024-02-03 12:21:00', 'ABT', 'Abbott Labs must face lawsuit over PediaSure height claims', 'false', 'false', 'true')
# ('2024-02-07 11:07:00', 'ENPH', 'Why Is Enphase Stock Up 20% After a Triple Miss?', 'false', 'false', 'true')
# ('2024-02-08 13:01:00', 'WYNN', 'These Stocks Are Moving the Most Today: Arm, Disney, PayPal, Confluent, Monolithic Power, Ralph Lauren, and More', 'false', 'false', 'true')
# ('2024-01-30 11:49:00', 'AWK', "American Water's (AWK) New Jersey Arm Invests in Upgrades", 'false', 'false', 'true')
# ('2024-02-18 12:57:00', 'MSFT', 'OpenAI valued at $80B after deal: report', 'false', 'true', 'true')
# ('2024-02-09 14:11:00', 'CMG', 'Uber, Chipotle, Disney, and Ford: Earnings Recap', 'false', 'false', 'true')
# ('2024-01-30 07:03:00', 'MSCI', 'MSCI: Q4 Earnings Snapshot', 'false', 'false', 'true')
# ('2024-01-25 05:21:00', 'MRNA', '3 S&P 500 Stocks With 127% to 170% Upside in 2024, According to Select Wall Street Analysts', 'false', 'false', 'true')
# ('2024-02-06 09:40:00', 'CI', 'Cigna (CI) is a Top-Ranked Value Stock: Should You Buy?', 'false', 'false', 'true')
# ('2024-01-26 17:31:00', 'CRM', 'What lies ahead for the tech sector after all these layoffs', 'false', 'false', 'true')
# ('2024-01-26 04:30:00', 'LRCX', 'Tech war: strong China demand for chip tools bolsters revenue at Lam Research and ASML despite US trade sanctions', 'false', 'false', 'true')
# ('2024-02-15 16:01:00', 'AMAT', 'Applied Materials Announces First Quarter 2024 Results', 'false', 'true', 'true')
# ('2024-02-15 12:50:00', 'JPM', 'JPMorgan, State Street Leave Biggest Climate-Investor Group', 'false', 'true', 'true')
# ('2024-02-08 10:35:00', 'K', "Kellanova (K) Stock Up on Former Kellogg's Q4 Earnings Beat", 'false', 'false', 'true')
# ('2024-02-08 09:00:00', 'MAR', "Marriott (MAR) Gears Up for Q4 Earnings: What's in Store?", 'false', 'false', 'true')
# ('2024-01-31 09:30:00', 'ODFL', 'Compared to Estimates, Old Dominion (ODFL) Q4 Earnings: A Look at Key Metrics', 'false', 'false', 'true')
# ('2024-02-03 07:45:00', 'ABT', 'Is Abbott Laboratories Stock a Buy Now?', 'false', 'false', 'true')
# ('2024-02-07 10:50:00', 'ENPH', 'Enphase Energy, Inc. (NASDAQ:ENPH) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-02-08 10:11:00', 'WYNN', 'Wynn Resorts (WYNN) Q4 Earnings & Revenues Beat Estimates', 'false', 'false', 'true')
# ('2024-01-30 11:00:00', 'AWK', 'American Water Charitable Foundation Donated $3.5 Million in 2023 to Support and Strengthen Communities', 'false', 'false', 'true')
# ('2024-02-09 07:25:00', 'CMG', 'Chipotles CFO on burrito season, the right amount of guacand why a price hike is coming to California', 'false', 'false', 'true')
# ('2024-02-18 11:23:00', 'MSFT', '3 Millionaire-Maker Technology Stocks', 'false', 'true', 'true')
# ('2024-01-30 06:45:00', 'MSCI', 'MSCI Reports Financial Results for Fourth Quarter and Full Year 2023', 'false', 'false', 'true')
# ('2024-01-24 17:50:00', 'MRNA', 'Moderna (MRNA) Stock Declines While Market Improves: Some Information for Investors', 'false', 'false', 'true')
# ('2024-02-05 13:00:00', 'CI', 'The Cigna Group Named No. 6 Among Best Corporate Citizens by JUST Capital and CNBC', 'false', 'false', 'true')
# ('2024-01-25 10:54:00', 'LRCX', 'Why Lam Research (LRCX) Stock Is Trading Up Today', 'false', 'false', 'true')
# ('2024-01-26 13:21:00', 'CRM', 'Salesforce Cuts 700 Jobs in Latest Big Tech Layoff', 'false', 'false', 'true')
# ('2024-02-15 10:33:00', 'AMAT', 'How To Earn $500 A Month From Applied Materials Stock Ahead Of Q1 Earnings Report', 'false', 'true', 'true')
# ('2024-02-15 12:25:00', 'JPM', 'J.P. Morgan Asset Management Launches 2024 College Planning Essentials Guide', 'false', 'true', 'true')
# ('2024-02-06 10:00:00', 'MAR', "Marriott International (MAR) Earnings Expected to Grow: What to Know Ahead of Next Week's Release", 'false', 'false', 'true')
# ('2024-02-08 09:38:00', 'K', 'Hershey, Kellanova Project Slower Sales Growth as High Prices Trouble Snack Habits', 'false', 'false', 'true')
# ('2024-02-02 12:15:00', 'ABT', "Can a 'Food as Medicine' Approach Help Manage Diabetes?", 'false', 'false', 'true')
# ('2024-01-31 08:16:00', 'ODFL', 'Old Dominion reports upbeat quarterly profit on higher shipments', 'false', 'false', 'true')
# ('2024-02-07 10:44:00', 'ENPH', 'Why Enphase Energy Shares Are Shining Today', 'false', 'false', 'true')
# ('2024-01-26 15:11:00', 'AWK', '13 Best Utility Dividend Stocks To Buy', 'false', 'false', 'true')
# ('2024-02-08 09:16:00', 'WYNN', 'Wynn Resorts, Limited (NASDAQ:WYNN) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-02-09 05:12:00', 'CMG', "Chipotle Just Smashed Wall Street's Expectations: 2 Big Ingredients Investors Can Thank for Its Success", 'false', 'false', 'true')
# ('2024-02-18 10:12:00', 'MSFT', 'Dow Futures: Nvidia Earnings Are Huge Test For AI-Led Rally; Super Micro Suffers Climax Top', 'false', 'true', 'true')
# ('2024-01-26 15:38:00', 'MSCI', 'EMERGING MARKETS-Latam stock and forex indexes rise after U.S. inflation data, set for weekly gains', 'false', 'false', 'true')
# ('2024-01-22 13:39:00', 'MRNA', 'Highlights From the 2024 JPMorgan Health Care Conference', 'false', 'false', 'true')
# ('2024-02-05 10:10:00', 'CI', "Charter downgraded, Cigna upgraded: Wall Street's top analyst calls", 'false', 'false', 'true')
# ('2024-01-26 09:50:00', 'CRM', 'Salesforce Layoffs 2024: What to Know About the Latest CRM Job Cuts', 'false', 'false', 'true')
# ('2024-01-25 10:52:00', 'LRCX', "Cramer's Mad Dash: Lam Research", 'false', 'false', 'true')
# ('2024-02-15 09:43:00', 'AMAT', 'China Chip Stocks Look Like Long-Term Winners to Wall Street', 'false', 'true', 'true')
# ('2024-02-15 12:00:00', 'JPM', 'All You Need to Know About JPMorgan Chase & Co. (JPM) Rating Upgrade to Buy', 'false', 'true', 'true')
# ('2024-02-05 12:10:00', 'MAR', 'Will Marriott (MAR) Beat Estimates Again in Its Next Earnings Report?', 'false', 'false', 'true')
# ('2024-02-08 08:33:00', 'K', 'Kellanova (NYSE:K) Beats Q4 Sales Targets', 'false', 'false', 'true')
# ('2024-02-02 05:03:00', 'ABT', 'Could Abbott Labs Be the Next Big Winner in the Billion-Dollar Weight Loss Market?', 'false', 'false', 'true')
# ('2024-01-31 08:10:00', 'ODFL', 'Old Dominion Freight Line (ODFL) Q4 Earnings Top Estimates', 'false', 'false', 'true')
# ('2024-02-07 10:32:00', 'ENPH', "Amgen downgraded, Enphase upgraded: Wall Street's top analyst calls", 'false', 'false', 'true')
# ('2024-01-25 16:10:00', 'AWK', 'Illinois American Water Files Rate Request Driven by $557 Million in Future Investments', 'false', 'false', 'true')
# ('2024-02-09 00:28:00', 'CMG', 'Decoding Chipotle Mexican Grill Inc (CMG): A Strategic SWOT Insight', 'false', 'false', 'true')
# ('2024-02-08 08:35:00', 'WYNN', 'Q4 2023 Wynn Resorts Ltd Earnings Call', 'false', 'false', 'true')
# ('2024-02-18 08:10:00', 'MSFT', '5 Portfolio Moves to Make If You Think the Stock Market Rally Is Nearing an End', 'false', 'true', 'true')
# ('2024-01-26 09:53:00', 'MSCI', 'China Stocks Lost Decade Means an Uphill Battle to Regain Trust', 'false', 'false', 'true')
# ('2024-01-22 11:02:00', 'MRNA', '12 S&P 500 Stocks On the Move', 'false', 'false', 'true')
# ('2024-02-05 08:18:00', 'CI', 'The Cigna Group Announces Commencement of Tender Offers for up to $2.25 Billion in Aggregate Principal Amount of Outstanding Notes', 'false', 'false', 'true')
# ('2024-01-25 10:49:00', 'LRCX', 'Lam Research Corporation (NASDAQ:LRCX) Q2 2024 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-01-26 09:44:00', 'CRM', 'Salesforce plans to lay off 700 workers: WSJ', 'false', 'false', 'true')
# ('2024-02-15 08:54:00', 'AMAT', '3 No-Brainer Semiconductor Stocks to Turn $10,000 Into $100,000 by 2028', 'false', 'true', 'true')
# ('2024-02-15 10:00:00', 'JPM', 'Banking Giant JP Morgan Exits Climate Action Group', 'false', 'true', 'true')
# ('2024-02-08 08:00:00', 'K', 'Kellanova Reports 2023 Fourth Quarter Results', 'false', 'false', 'true')
# ('2024-02-01 12:00:00', 'MAR', 'The Ritz-Carlton Dallas, Las Colinas Opens, Unveiling Multimillion Dollar Renovation', 'false', 'false', 'true')
# ('2024-02-01 15:01:00', 'ABT', 'Executive Vice President Andrea Wainer Sells 42,500 Shares of Abbott Laboratories', 'false', 'false', 'true')
# ('2024-01-31 07:17:00', 'ODFL', 'Old Dominion: Q4 Earnings Snapshot', 'false', 'false', 'true')
# ('2024-02-07 10:14:00', 'ENPH', 'Q4 2023 Enphase Energy Inc Earnings Call', 'false', 'false', 'true')
# ('2024-01-25 09:35:00', 'AWK', "Down -7.78% in 4 Weeks, Here's Why You Should You Buy the Dip in American Water Works (AWK)", 'false', 'false', 'true')
# ('2024-02-08 06:00:00', 'CMG', "Why Chipotle's eye-popping results show a long runway for the brand", 'false', 'false', 'true')
# ('2024-02-08 07:56:00', 'WYNN', 'Wynn Resorts Announces Private Add-On Offering of $400 Million of Wynn Resorts Finance 7.125% Senior Notes due 2031', 'false', 'false', 'true')
# ('2024-02-18 07:40:00', 'MSFT', 'Billionaire Investor Chase Coleman Has 46% of His Portfolio Invested in 5 Brilliant Artificial Intelligence (AI) Growth Stocks', 'false', 'true', 'true')
# ('2024-01-25 12:10:00', 'MSCI', 'Will MSCI (MSCI) Beat Estimates Again in Its Next Earnings Report?', 'false', 'false', 'true')
# ('2024-01-21 10:16:00', 'MRNA', 'If You Invested $10,000 in Moderna at the End of 2019, This Is How Much You Would Have Today', 'false', 'false', 'true')
# ('2024-02-03 08:51:00', 'CI', 'Cigna Corporation (NYSE:CI) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-01-25 10:22:00', 'LRCX', "Lam Research's (LRCX) Q2 Earnings Beat, Revenues Down Y/Y", 'false', 'false', 'true')
# ('2024-01-26 09:23:00', 'CRM', 'Salesforce to Cut About 700 Workers, Adding to Tech Layoff Flood', 'false', 'false', 'true')
# ('2024-02-15 09:25:00', 'JPM', "It's going to be 'two steps forward, one step back' with inflation, says JPMorgan's Meera Pandit", 'false', 'true', 'true')
# ('2024-02-14 20:38:00', 'AMAT', 'Samsung embraces hybrid bonding for advanced non-memory packaging', 'false', 'true', 'true')
# ('2024-02-01 09:40:00', 'MAR', "Here's Why Marriott International (MAR) is a Strong Value Stock", 'false', 'false', 'true')
# ('2024-02-07 17:28:00', 'K', 'Earnings, Fedspeak, jobless claims: What to watch', 'false', 'false', 'true')
# ('2024-02-01 09:00:00', 'ABT', 'New Study Shows Mixed Reality Technology for Blood Donation from Abbott and Blood Centers of America Helps Ease Stress, Encourages People to Donate Again', 'false', 'false', 'true')
# ('2024-01-31 07:00:00', 'ODFL', 'Old Dominion Freight Line Reports Fourth Quarter 2023 Earnings Per Diluted Share of $2.94', 'false', 'false', 'true')
# ('2024-02-17 00:14:00', 'TROW', 'Decoding T. Rowe Price Group Inc (TROW): A Strategic SWOT Insight', 'false', 'true', 'true')
# ('2024-02-07 10:11:00', 'ENPH', 'Why Is Enphase Energy (ENPH) Stock Up 15% Today?', 'false', 'false', 'true')
# ('2024-02-08 03:30:00', 'CMG', 'How Chipotle plans to reach $4M AUVs', 'false', 'false', 'true')
# ('2024-02-08 06:56:00', 'WYNN', 'Disney Delights Its Investor Audience but Its Probably Not Enough Magic for Activists, and 5 Other Things to Know Before Markets Open.', 'false', 'false', 'true')
# ('2024-02-18 07:30:00', 'MSFT', '3 Top Tech Stocks to Buy in February', 'false', 'true', 'true')
# ('2024-01-25 10:36:00', 'MSCI', 'Colombia Is Moving to Fend Off Frontier Status for Its Fading Stock Market', 'false', 'false', 'true')
# ('2024-01-31 09:45:00', 'MAR', 'Why Marriott International (MAR) is a Top Growth Stock for the Long-Term', 'false', 'false', 'true')
# ('2024-01-21 08:53:00', 'MRNA', '1 Stock Down 43% to Buy and Hold for 10 Years', 'false', 'false', 'true')
# ('2024-02-03 00:11:00', 'CI', 'Q4 2023 Cigna Group Earnings Call', 'false', 'false', 'true')
# ('2024-01-26 08:33:00', 'CRM', 'Salesforce Cuts 700 Jobs in Streamlining Effort, Yet Eyes Growth with 1,000 Open Roles', 'false', 'false', 'true')
# ('2024-01-25 08:28:00', 'LRCX', 'Q2 2024 Lam Research Corp Earnings Call', 'false', 'false', 'true')
# ('2024-02-14 02:02:00', 'AMAT', 'Applied Materials (AMAT) To Report Earnings Tomorrow: Here Is What To Expect', 'false', 'true', 'true')
# ('2024-02-15 06:40:00', 'JPM', 'UPDATE 5-JPMorgan, State Street quit climate group, BlackRock steps back', 'false', 'true', 'true')
# ('2024-02-05 09:15:00', 'K', "CHRIS PRATT IS MR. P: PRINGLES 2024 BIG GAME AD SPOT SHOWS THE HOLLYWOOD STAR'S UNCANNY RESEMBLENCE TO THE ICONIC MUSTACHED CHARACTER", 'false', 'false', 'true')
# ('2024-02-16 06:54:00', 'TROW', 'Analyst Report: T. Rowe Price Group, Inc.', 'false', 'true', 'true')
# ('2024-02-01 07:46:00', 'ABT', "Drugmaker Abbott India's Q3 profit rises on strong demand", 'false', 'false', 'true')
# ('2024-01-29 08:51:00', 'ODFL', "Old Dominion (ODFL) Gears Up for Q4 Earnings: What's in Store?", 'false', 'false', 'true')
# ('2024-02-07 18:12:00', 'CMG', 'Chipotle delivers strong Q4; to open 285 to 315 new locations in 2024', 'false', 'false', 'true')
# ('2024-02-07 09:41:00', 'ENPH', 'Enphase Stock Is Soaring. The CEO Has Called a Bottom.', 'false', 'false', 'true')
# ('2024-02-08 04:10:00', 'WYNN', 'Wynn Resorts Receives 22 Five-Star Awards from Forbes Travel Guide on 2024 List', 'false', 'false', 'true')
# ('2024-02-18 07:00:00', 'MSFT', 'Stock-Split Watch: Is Microsoft Next?', 'false', 'true', 'true')
# ('2024-01-25 09:15:00', 'MSCI', 'Countdown to MSCI (MSCI) Q4 Earnings: A Look at Estimates Beyond Revenue and EPS', 'false', 'false', 'true')
# ('2024-01-26 10:30:00', 'MAR', 'Marriott (MAR) Plans Expansion of Apartments by Marriott Bonvoy', 'false', 'false', 'true')
# ('2024-02-12 19:19:00', 'EXR', 'Analyst Report: Extra Space Storage Inc.', 'false', 'false', 'true')
# ('2024-01-26 05:39:00', 'CRM', 'Salesforce Cutting 1% of Its Workforce, Report Says. Its Not Helping the Stock.', 'false', 'false', 'true')
# ('2024-02-02 19:40:00', 'CI', 'Analyst Report: The Cigna Group', 'false', 'false', 'true')
# ('2024-01-24 22:35:00', 'LRCX', 'Analyst Report: Lam Research Corporation', 'false', 'false', 'true')
# ('2024-02-12 14:13:00', 'AMAT', 'Calls of the Day: Applied Materials, Arista Networks and Netflix', 'false', 'false', 'true')
# ('2024-02-15 05:49:00', 'JPM', 'Global Banks Boost India Bond Marketing as Index Day Nears', 'false', 'true', 'true')
# ('2024-02-02 12:00:00', 'K', 'Kellanova to Webcast Presentation at 2024 CAGNY Conference', 'false', 'false', 'true')
# ('2024-02-15 10:57:00', 'TROW', 'OHA is a Joint Lead Arranger of Private Unitranche Financing for Clarience Technologies Acquisition of Safe Fleet', 'false', 'true', 'true')
# ('2024-02-07 15:47:00', 'CMG', 'Analyst Report: Chipotle Mexican Grill, Inc.', 'false', 'false', 'true')
# ('2024-02-01 00:06:00', 'ABT', '15 Highest Quality Creatine Supplements of 2024', 'false', 'false', 'true')
# ('2024-01-26 09:15:00', 'ODFL', 'Unveiling Old Dominion (ODFL) Q4 Outlook: Wall Street Estimates for Key Metrics', 'false', 'false', 'true')
# ('2024-02-07 09:13:00', 'ENPH', 'Enphase Energy (ENPH) Q4 Earnings Meet, Revenues Fall Y/Y', 'false', 'false', 'true')
# ('2024-02-07 23:34:00', 'WYNN', 'Analyst Report: Wynn Resorts, Limited', 'false', 'false', 'true')
# ('2024-02-18 06:25:00', 'MSFT', 'Is Arm Holdings the Next Nvidia After Smashing Earnings Estimates?', 'false', 'true', 'true')
# ('2024-01-24 11:46:00', 'MAR', 'Marriott (MAR) Announces Strategic Partnership With Delonix', 'false', 'false', 'true')
# ('2024-01-25 06:31:00', 'MSCI', "Here's Why FMC Corporation (FMC) Fell in Q4", 'false', 'false', 'true')
# ('2024-02-12 12:03:00', 'EXR', 'The 3 Worst-Performing S&P 500 Stocks to Buy Before They Rebound', 'false', 'false', 'true')
# ('2024-02-02 15:15:00', 'CI', 'Cigna Group (CI) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-01-26 02:00:00', 'CRM', 'UPDATE 1-Salesforce laying off 700 workers in latest tech industry downsizing - WSJ', 'false', 'false', 'true')
# ('2024-01-24 22:00:00', 'LRCX', 'Lam Research (LRCX) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-02-12 11:43:00', 'AMAT', "Applied Materials (AMAT) to Post Q1 Earnings: What's in Store?", 'false', 'false', 'true')
# ('2024-02-15 05:02:00', 'JPM', 'JPMorgan, State Street quit climate group, BlackRock steps back', 'false', 'true', 'true')
# ('2024-02-01 08:00:00', 'K', "Galentine's Day with Kellanova: Love at first bite", 'false', 'false', 'true')
# ('2024-02-14 00:40:00', 'TROW', '20 Cheapest Places to Retire with Good Healthcare', 'false', 'true', 'true')
# ('2024-02-07 15:07:00', 'CMG', 'Chipotle CEO Brian Niccol Says Doubling the Chain\'s Restaurant Count to 7,000 is "Feasible in the Long Term"', 'false', 'false', 'true')
# ('2024-01-31 21:03:00', 'ABT', 'LLY, ABT, CVS: Which Healthcare Stock Do Analysts Prefer?', 'false', 'false', 'true')
# ('2024-01-24 10:00:00', 'ODFL', 'Earnings Preview: Old Dominion Freight Line (ODFL) Q4 Earnings Expected to Decline', 'false', 'false', 'true')
# ('2024-02-06 23:30:00', 'ENPH', 'Enphase Energy (ENPH) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-02-07 22:30:00', 'WYNN', 'Wynn Resorts (WYNN) Q4 2023 Earnings Call Transcript', 'false', 'false', 'true')
# ('2024-02-18 06:20:00', 'MSFT', 'SoundHound AI Stock Soared Last Week, but Does That Make It a Buy?', 'false', 'true', 'true')
# ('2024-01-24 09:00:00', 'MAR', 'Marriott International, Inc. (MAR) Is a Trending Stock: Facts to Know Before Betting on It', 'false', 'false', 'true')
# ('2024-01-25 06:14:00', 'MSCI', "Aristotle Capital Global Equity Strategy's Q4 2023 Investor Letter", 'false', 'false', 'true')
# ('2024-01-30 11:04:00', 'EXR', 'The Ultimate REIT Hack to Capitalize on Downsized Living: Maximize Space and Profits', 'false', 'false', 'true')
# ('2024-01-26 01:13:00', 'CRM', 'Salesforce laying off 700 workers in latest tech job cuts: WSJ', 'false', 'false', 'true')
# ('2024-02-02 15:04:00', 'CI', 'AM Best Comments on Health Care Service Corporations Planned Acquisition of The Cigna Groups Medicare Business', 'false', 'false', 'true')
# ('2024-01-24 17:31:00', 'LRCX', 'Chip Gear Vendor Lam Research Tops December-Quarter Views, Guides Up', 'false', 'false', 'true')
# ('2024-02-12 09:16:00', 'AMAT', 'Gear Up for Applied Materials (AMAT) Q1 Earnings: Wall Street Estimates for Key Metrics', 'false', 'false', 'true')
# ('2024-02-15 04:44:00', 'JPM', 'JPMorgan fund arm quits Climate Action 100+ investor group', 'false', 'true', 'true')
# ('2024-01-30 09:52:00', 'K', 'Kellanova set to achieve 90 percent renewable electricity across North America in 2024', 'false', 'false', 'true')
# ('2024-02-13 12:29:00', 'TROW', "T. Rowe Price's (TROW) January AUM Rises Marginally to $1.45T", 'false', 'true', 'true')
# ('2024-02-07 14:52:00', 'CMG', 'Chipotle Stock Surges to a Fresh Record as Higher Prices and Foot Traffic Boost Earnings', 'false', 'false', 'true')
# ('2024-01-31 13:13:00', 'ABT', 'Abbott Rolls Out Protein Shake Amid Weight Loss Drug Craze', 'false', 'false', 'true')
# ...
# ('2024-01-30 16:48:00', 'MTCH', 'Match Group Inc (MTCH) Posts Strong Earnings Amid Operational Efficiency and Revenue Growth', 'false', 'false', 'true')
# ('2024-02-20 02:07:00', 'LRCX', "South Korean chip tool makers voice apprehension over SIA's lobby to expand export ban", 'true', 'true', 'true')
# ('2024-02-14 11:09:00', 'TSLA', 'Invest Like Elon Musk With This Hack', 'false', 'true', 'true')
# ('2024-02-16 15:26:00', 'AMAT', 'Stocks to Watch Friday: Coinbase, Roku, DraftKings, Nike', 'false', 'true', 'true')
# ('2024-02-16 03:35:00', 'CF', 'Q4 2023 CF Industries Holdings Inc Earnings Call', 'false', 'true', 'true')
# ('2024-02-15 05:37:00', 'AWK', "American Water (AWK) Q4 Earnings Beat Estimates, '24 View Up", 'false', 'true', 'true')
# ('2024-02-07 16:44:00', 'CRM', 'Dorsal Capital Partners Sees a 13% Boost in 2023: Its Top 15 Stock Picks', 'false', 'false', 'true')
# ('2024-01-27 10:00:00', 'BMY', 'Subcutaneous Nivolumab (nivolumab and hyaluronidase) Shows Noninferiority Compared to Intravenous Opdivo (nivolumab) in Advanced or Metastatic Clear Cell Renal Cell Carcinoma in CheckMate -67T Trial', 'false', 'false', 'true')
# ('2024-02-14 17:45:00', 'MRNA', "Here's Why Moderna (MRNA) Gained But Lagged the Market Today", 'false', 'true', 'true')
# ('2024-02-08 06:48:00', 'NWS', 'News Corp Stock Rises as Surge in Digital Subs Offsets Weak Ad Revenue Key Level to Watch', 'false', 'false', 'true')
# ('2024-01-30 16:23:00', 'MTCH', "Match Group's (NASDAQ:MTCH) Q4 Earnings Results: Revenue In Line With Expectations But Quarterly Guidance Underwhelms", 'false', 'false', 'true')
# ('2024-02-13 13:21:00', 'LRCX', 'Trade Tracker: Stephanie Link trims Lam Research and Broadcom', 'false', 'true', 'true')
# ('2024-02-14 11:04:00', 'TSLA', 'What To Watch: Nvidia Earnings', 'false', 'true', 'true')
# ('2024-02-16 13:14:00', 'AMAT', 'These Stocks Are Moving the Most Today: Coinbase, Super Micro, Trade Desk, Roku, Dropbox, Bloom Energy, and More', 'false', 'true', 'true')
# ('2024-02-15 05:53:00', 'CF', "CF Industries' (CF) Q4 Earnings Lag, Lower Prices Hurt Sales", 'false', 'true', 'true')
# ('2024-02-15 00:14:00', 'AWK', 'Decoding American Water Works Co Inc (AWK): A Strategic SWOT Insight', 'false', 'true', 'true')
# ('2024-02-07 16:30:00', 'CRM', 'Salesforce Announces Timing of its Fourth Quarter and Full Year Fiscal 2024 Results Conference Call', 'false', 'false', 'true')
# ('2024-01-26 07:13:00', 'BMY', 'Bristol Myers Squibb Receives Positive CHMP Opinion for CAR T Cell Therapy Abecma (idecabtagene vicleucel) in Earlier Lines of Therapy for Triple-Class Exposed Relapsed and Refractory Multiple Myeloma', 'false', 'false', 'true')
# ('2024-02-08 06:00:00', 'NWS', 'Realtor.com Avail Survey Finds Despite Cooling Rental Prices, Homeownership Remains Out of Reach for Many', 'false', 'false', 'true')
# ('2024-02-13 17:36:00', 'MRNA', '5 Highest Quality Pasta Brands In The US', 'false', 'true', 'true')
# ('2024-01-30 16:13:00', 'MTCH', 'Tinder-parent Match forecasts weak revenue on lower spending on dating apps', 'false', 'false', 'true')
# ('2024-02-08 16:05:00', 'LRCX', 'Lam Research Corporation Declares Quarterly Dividend', 'false', 'false', 'true')
# ('2024-02-14 10:39:00', 'TSLA', 'Is Tesla Stock a Buy?', 'false', 'true', 'true')
# ('2024-02-16 12:45:00', 'AMAT', 'Top Stock Movers Now: Nike, Applied Materials, Roku, and More', 'false', 'true', 'true')
# ('2024-02-14 21:43:00', 'CF', 'INSERTING and REPLACING CF Industries Holdings, Inc. Reports Full Year 2023 Net Earnings of $1.53 Billion, Adjusted EBITDA of $2.76 Billion', 'false', 'true', 'true')
# ('2024-02-14 17:50:00', 'AWK', 'American Water Works (AWK) Surpasses Q4 Earnings and Revenue Estimates', 'false', 'true', 'true')
# ('2024-02-07 15:04:00', 'CRM', '10 Best Stocks To Invest In 2024 For Beginners', 'false', 'false', 'true')
# ('2024-02-13 07:00:00', 'MRNA', '2 Stocks Down 36% or More to Buy and Hold for 10 Years', 'false', 'true', 'true')
# ('2024-02-07 17:55:00', 'NWS', 'News Corps Earnings, Revenue Rise on Subscription Growth', 'false', 'false', 'true')
# ('2024-01-30 16:11:00', 'MTCH', 'Match Group Reports Fourth Quarter 2023 Results', 'false', 'false', 'true')
# ('2024-02-14 10:13:00', 'TSLA', 'UPDATE 2-Musk, Tesla shareholder to propose a stay of pay ruling during appeal', 'false', 'true', 'true')
# ('2024-02-16 12:11:00', 'AMAT', 'These Stocks Are Moving the Most Today', 'false', 'true', 'true')
# ('2024-02-14 18:30:00', 'CF', 'CF (CF) Q4 Earnings: Taking a Look at Key Metrics Versus Estimates', 'false', 'true', 'true')
# ('2024-02-07 09:30:00', 'CRM', 'Brokers Suggest Investing in Salesforce.com (CRM): Read This Before Placing a Bet', 'false', 'false', 'true')
# ('2024-02-07 16:44:00', 'NWS', 'News Corp (NASDAQ:NWSA) Surprises With Q2 Sales', 'false', 'false', 'true')
# ('2024-02-11 17:00:00', 'MRNA', '3 Doomed Biotech Stocks to Dump Before They Dive: February 2024', 'false', 'false', 'true')
# ('2024-01-29 11:15:00', 'MTCH', "Match Group (MTCH) to Post Q4 Earnings: What's in Store?", 'false', 'false', 'true')
# ('2024-02-14 09:53:00', 'TSLA', 'Musk, Tesla shareholder to propose a stay of pay ruling during appeal', 'false', 'true', 'true')
# ('2024-02-16 11:41:00', 'AMAT', 'Applied Materials (AMAT) Shares Skyrocket, What You Need To Know', 'false', 'true', 'true')
# ('2024-02-14 18:02:00', 'CF', 'Top Corn Fertilizer Maker Sees Profit Plunge as Prices Tumble', 'false', 'true', 'true')
# ('2024-02-07 05:45:00', 'CRM', "This Artificial Intelligence (AI) Stock Topped the Dow Jones Last Year. Here's Why I Think It'll Do It Again in 2024.", 'false', 'false', 'true')
# ('2024-02-10 17:09:00', 'MRNA', 'Top 11 CRISPR Stocks To Invest In', 'false', 'false', 'true')
# ('2024-02-07 16:35:00', 'NWS', 'News Corp (NWSA) Reports Strong Earnings Growth in Q2 FY2024', 'false', 'false', 'true')
# ('2024-02-14 09:40:00', 'TSLA', 'Musk, Tesla shareholder to propose a stay of pay ruling during appeal - court filing', 'false', 'true', 'true')
# ('2024-02-16 11:41:00', 'AMAT', 'Applied Materials (AMAT) Q1 Earnings Beat, Sales Dip Y/Y', 'false', 'true', 'true')
# ('2024-02-14 17:50:00', 'CF', 'CF Industries (CF) Q4 Earnings Miss Estimates', 'false', 'true', 'true')
# ('2024-02-10 08:30:00', 'MRNA', '30 Most Valuable Drug Companies in 2024', 'false', 'false', 'true')('2024-02-07 16:34:00', 'NWS', 'News Corp.: Fiscal Q2 Earnings Snapshot', 'false', 'false', 'true')
#
# ('2024-02-14 09:03:00', 'TSLA', 'Swedish union to exempt some Tesla cars from mechanic strike', 'false', 'true', 'true')
# ('2024-02-16 10:45:00', 'AMAT', 'Why Applied Materials Stock Just Jumped 7%', 'false', 'true', 'true')
# ('2024-02-14 17:36:00', 'CF', 'CF Industries lower quarterly profit slumps nearly 70%', 'false', 'true', 'true')
# ('2024-02-09 16:28:00', 'MRNA', 'Moderna stock falls following new RSV vaccine efficacy data', 'false', 'false', 'true')
# ('2024-02-07 16:27:00', 'NWS', 'UPDATE 3-News Corp beats revenue estimates on digital real estate services growth', 'false', 'false', 'true')
# ('2024-02-14 08:30:00', 'TSLA', 'The Electrifying Rise of Electric Boats', 'false', 'true', 'true')
# ('2024-02-16 10:36:00', 'AMAT', 'Applied Materials, Inc. (NASDAQ:AMAT) Q1 2024 Earnings Call Transcript', 'false', 'true', 'true')
# ('2024-02-14 17:16:00', 'CF', 'CF Industries Holdings Inc Reports Full Year 2023 Earnings Amidst Global Energy Shifts', 'false', 'true', 'true')
# ('2024-02-09 14:35:00', 'MRNA', "Moderna's stock slumps after RSV shot efficacy wanes faster than GSK's Arexvy", 'false', 'false', 'true')
# ('2024-02-07 16:18:00', 'NWS', 'News Corp beats revenue estimates on digital real estate services growth', 'false', 'false', 'true')
# ('2024-02-14 08:23:00', 'TSLA', 'Tesla Repair-Shop Blockade Temporarily Lifted by Swedish Union', 'false', 'true', 'true')
# ('2024-02-16 09:33:00', 'AMAT', 'Analyst Report: Applied Materials, Inc.', 'false', 'true', 'true')
# ('2024-02-14 16:53:00', 'CF', 'CF: Q4 Earnings Snapshot', 'false', 'true', 'true')
# ('2024-02-09 14:33:00', 'MRNA', 'Moderna, Bayer-backed Metagenomi stock drops 32% on Nasdaq debut', 'false', 'false', 'true')
# ('2024-02-07 16:17:00', 'NWS', 'News Corp beats quarterly revenue estimates', 'false', 'false', 'true')
# ('2024-02-14 07:58:00', 'TSLA', 'Elon Musk Has a Lot to Say About Ukraine. And a Lot to Learn.', 'false', 'true', 'true')
# ('2024-02-16 08:14:00', 'AMAT', 'Analysts unveil new Applied Materials stock price targets on AI outlook', 'false', 'true', 'true')
# ('2024-02-14 16:30:00', 'CF', 'CF Industries Holdings, Inc. Reports Full Year 2023 Net Earnings of $1.53 Billion, Adjusted EBITDA of $2.76 Billion', 'false', 'true', 'true')
# ('2024-02-09 13:21:00', 'MRNA', 'Modernas RSV Vaccine May Lose Efficacy Faster Than GSK and Pfizers', 'false', 'false', 'true')
# ('2024-02-07 16:15:00', 'NWS', 'News Corporation Reports Second Quarter Results for Fiscal 2024', 'false', 'false', 'true')
# ('2024-02-14 07:52:00', 'TSLA', "Tesla updated its Autopilot but apparently it's still not safe enough", 'false', 'true', 'true')
# ('2024-02-16 07:43:00', 'AMAT', 'Applied Materials Stock Pops On Earnings Beat Amid Advanced Chip Demand Indicator to Watch', 'false', 'true', 'true')
# ('2024-02-09 09:15:00', 'CF', 'Insights Into CF (CF) Q4: Wall Street Projections for Key Metrics', 'false', 'false', 'true')
# ('2024-02-09 10:28:00', 'MRNA', 'Moderna shares slide on concerns over drop in RSV vaccine efficacy (Feb 9)', 'false', 'false', 'true')
# ('2024-02-01 06:00:00', 'NWS', 'Realtor.com January Housing Report: January 2024 Marks the Third Consecutive Month of Annual Inventory Growth', 'false', 'false', 'true')
# ('2024-02-14 06:01:00', 'TSLA', "Explainer-Did Delaware 'lock the doors' to stop companies from leaving, as Musk claims?", 'false', 'true', 'true')
# ('2024-02-16 07:35:00', 'AMAT', 'US STOCKS-S&P, Nasdaq futures rise ahead of inflation data; Applied Materials surges', 'false', 'true', 'true')
# ('2024-02-08 07:01:00', 'CF', "CF Industries (CF) to Report Q4 Earnings: What's in Store?", 'false', 'false', 'true')
# ('2024-02-09 00:41:00', 'MRNA', 'UPDATE 1-Moderna-backed Metagenomi cuts US IPO valuation target to $563 mln', 'false', 'false', 'true')
# ('2024-01-30 13:40:00', 'NWS', 'WSJ plans to restructure Washington bureau, let go of some staff - Axios', 'false', 'false', 'true')
# ('2024-02-14 05:22:00', 'TSLA', '20 Most Reliable Cars For Seniors', 'false', 'true', 'true')
# ('2024-02-16 07:19:00', 'AMAT', '5 Things to Know Before The Stock Market Opens', 'false', 'true', 'true')
# ('2024-02-07 18:15:00', 'CF', 'CF Industries (CF) Gains But Lags Market: What You Should Know', 'false', 'false', 'true')
# ('2024-02-08 23:05:00', 'MRNA', 'Moderna-backed Metagenomi cuts US IPO valuation target to $563 mln', 'false', 'false', 'true')
# ('2024-01-30 09:01:00', 'NWS', 'Dow Jones Launches Risk & Compliance Financial Instruments', 'false', 'false', 'true')
# ('2024-02-14 05:06:00', 'TSLA', '3 Artificial Intelligence (AI) Stocks That Can Plunge 43% to 88%, According to Select Wall Street Analysts', 'false', 'true', 'true')
# ('2024-02-16 07:17:00', 'AMAT', 'Applied Materials shares rise after upbeat AI-boosted forecast', 'false', 'true', 'true')
# ('2024-02-07 15:37:00', 'CF', '15 Biggest Agriculture Stocks in 2024', 'false', 'false', 'true')
# ('2024-02-08 13:00:00', 'MRNA', 'Is Moderna Stock A Buy Or A Sell As Covid-Related Challenges Linger?', 'false', 'false', 'true')
# ('2024-01-25 09:00:00', 'NWS', 'Webull partners with Dow Jones to drive greater financial literacy and empower retail investing decisions', 'false', 'false', 'true')
# ('2024-02-14 04:00:00', 'TSLA', "Elon Musk wants to take away Delawares incorporation crown. It won't be easy.", 'false', 'true', 'true')
# ('2024-02-16 07:17:00', 'AMAT', 'Applied Materials gains on upbeat forecast as rising AI adoption drives chip tools demand', 'false', 'true', 'true')
# ('2024-02-07 10:00:00', 'CF', 'Earnings Preview: CF Industries (CF) Q4 Earnings Expected to Decline', 'false', 'false', 'true')
# ('2024-02-08 06:05:00', 'MRNA', 'If You Invested $10,000 in Moderna in 2019, This Is How Much You Would Have Today', 'false', 'false', 'true')
# ('2024-01-25 06:00:00', 'NWS', "Realtor.com December Rental Report: Price Peak Behind Us as Rents Continue to Fall at Year's End", 'false', 'false', 'true')
# ('2024-02-16 07:00:00', 'AMAT', 'Q1 2024 Applied Materials Inc Earnings Call', 'false', 'true', 'true')
# ('2024-02-13 23:17:00', 'TSLA', 'NIO vs. BYDDY: Which EV Stock Is the Better Buy?', 'false', 'true', 'true')
# ('2024-02-05 08:30:00', 'CF', 'Christopher D. Bohn Appointed Executive Vice President and Chief Operating Officer of CF Industries Holdings, Inc., Elected to Board of Directors', 'false', 'false', 'true')
# ('2024-02-07 17:45:00', 'MRNA', 'Moderna (MRNA) Stock Slides as Market Rises: Facts to Know Before You Trade', 'false', 'false', 'true')
# ('2024-01-23 16:30:00', 'NWS', 'News Corp to Report Fiscal 2024 Second Quarter Earnings', 'false', 'false', 'true')
# ('2024-02-16 06:18:00', 'AMAT', 'Wall St slips after hot producer prices data dents early rate-cut hopes', 'false', 'true', 'true')
# ('2024-02-13 22:17:00', 'TSLA', 'A job listing with pay ranging from $50,000 to $180,000? Not in good faith, says NYC commission', 'false', 'true', 'true')
# ('2024-02-01 18:15:00', 'CF', "CF Industries (CF) Laps the Stock Market: Here's Why", 'false', 'false', 'true')
# ('2024-02-07 12:13:00', 'MRNA', '2024 Promises To Bring Pharmaceutical Breakthroughs On The Oncology Front', 'false', 'false', 'true')
# ('2024-02-13 20:46:00', 'TSLA', 'Oil Edges Lower as Industry Report Points to Surge in Stockpiles', 'false', 'true', 'true')
# ('2024-01-31 16:30:00', 'CF', 'CF Industries Holdings, Inc. Announces 25% Increase in Quarterly Dividend', 'false', 'false', 'true')
# ('2024-02-13 18:39:00', 'TSLA', "Investors Have Piled Into 'Magnificent Seven' Stocks Why That May Not Be Good", 'false', 'true', 'true')
# ('2024-01-29 14:23:00', 'CF', 'Betting on Biden: 3 Stocks to Buy for a Democratic Future', 'false', 'false', 'true')
# ('2024-02-13 18:18:00', 'TSLA', 'Tesla Vs. BYD: TSLA, New EV King Struggle Amid Weak Earnings, Tough Climate', 'false', 'true', 'true')
# ('2024-01-26 18:15:00', 'CF', 'CF Industries (CF) Gains As Market Dips: What You Should Know', 'false', 'false', 'true')
# ('2024-02-13 17:15:00', 'TSLA', "The Next Elon Musk? 3 CEOs That Investors Shouldn't Ignore", 'false', 'true', 'true')
# ('2024-01-25 11:00:00', 'CF', 'Forget the Term ESG. But Dont Ignore the Power of the Concept.', 'false', 'false', 'true')
# ('2024-02-13 16:23:00', 'TSLA', 'Tesla Price Yo-Yo Continues With Model Y Hikes In Europe', 'false', 'true', 'true')
# ('2024-02-17 06:32:00', 'K', 'Why Investors Found WK Kellogg Stock So Tasty This Week', 'false', 'true', 'true')
# ('2024-02-13 15:51:00', 'TSLA', 'Power Trader Challenges Texas Grid Policy Over Price Spikes', 'false', 'true', 'true')
# ('2024-02-16 11:33:00', 'K', 'Kellanova Declares Regular Dividend of $0.56 per Share', 'false', 'true', 'true')
# ('2024-02-20 10:47:00', 'JPM', '12 Best Blue Chip Stocks To Invest In According to Hedge Funds', 'true', 'true', 'true')
# ('2024-02-15 11:20:00', 'K', 'WK Kellogg Co (NYSE:KLG) Q4 2023 Earnings Call Transcript', 'false', 'true', 'true')
# ('2024-02-20 10:43:00', 'JPM', 'JPMorgan (JPM) to Pay $350M Civil Penalty Over Reporting Lapses', 'true', 'true', 'true')
# ('2024-02-15 09:12:00', 'K', 'Fill Your Easter Basket with Egg-citing New Treats from Frankford Candy', 'false', 'true', 'true')
# ('2024-02-20 06:00:00', 'JPM', 'Navigating Market Uncertainty: Intrinsic Value of JPMorgan Chase & Co', 'true', 'true', 'true')
# ('2024-02-15 08:00:00', 'K', '5 Tech Priorities Shaping the Future of Kellanova', 'false', 'true', 'true')
# ('2024-02-18 09:57:00', 'JPM', 'How Texas came to rival New York as a finance hub', 'false', 'true', 'true')
# ('2024-02-14 12:08:00', 'K', 'William Post, who played a key role in developing Pop-Tarts, dies at 96', 'false', 'true', 'true')
# ('2024-02-14 09:13:00', 'K', 'William Bill Post, who helped invent Pop-Tarts, has died', 'false', 'true', 'true')
