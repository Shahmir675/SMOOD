# %% [markdown]
# ## Importing Dependencies

# %%
import psycopg2
import os
import pandas as pd
import torch
from transformers import BertForSequenceClassification, BertTokenizer
from tqdm.notebook import tqdm
from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# ## Connecting to Supabase

# %%
def get_connection():
    try:
        connection = psycopg2.connect(
            dbname=os.getenv('DB_NAME'),
            user=os.getenv('DB_USER'),
            password=os.getenv('DB_PASSWORD'),
            host=os.getenv('DB_HOST'),
            port=os.getenv('DB_PORT'),
        )

    except psycopg2.OperationalError as e:
        print(f'Error: {e}')
        return None

    else:
        print('Connected Established!')
        return connection

# %%
conn = get_connection()
# Out:
# Connected Established!

# %% [markdown]
# ## Extracting headlines

# %%
def extract_headlines():
    with conn.cursor() as curr:
        curr.execute("SELECT * FROM headlines")
        headlines = curr.fetchall()
        columns = [curr.description[i][0] for i in range(len(curr.description))]
        df = pd.DataFrame(headlines, columns=columns)
    return df

# %%
headlines = extract_headlines()

# %%
headlines.head(10)
# Out:
#   publication_timestamp ticker  \
# 0   2024-03-14 07:06:00    HES
# 1   2024-04-04 09:10:00    PEP
# 2   2024-03-19 19:24:00    ROL
# 3   2024-03-19 17:47:00   WELL
# 4   2024-04-08 07:02:00   ORCL
# 5   2024-04-03 20:53:00   COST
# 6   2024-03-28 13:00:00    BLK
# 7   2024-03-28 11:54:00    BLK
# 8   2024-03-28 10:24:00    BLK
# 9   2024-03-28 09:12:00    BLK
#
#                                             headline  is_daily  is_weekly  \
# 0                      Hess Corp's Dividend Analysis     False      False
# 1                                            PepsiCo     False       True
# 2                      Analyst Report: Rollins, Inc.     False      False
# 3                     Analyst Report: Welltower Inc.     False      False
# 4                    Oracle Corp's Dividend Analysis     False       True
# 5    Costco launches weight-loss program for members     False      False
# 6  BlackRock CEO Larry Fink Expresses Serious Con...     False      False
# 7  BlackRock CEO Larry Fink tells a 'tale of two ...     False      False
# 8  BlackRock's (BLK) Restructuring Efforts Aid Am...     False      False
# 9  UPDATE 1-US cryptocurrency ETF inflows pick up...     False      False
#
#    is_monthly sentiment
# 0        True   neutral
# 1        True   neutral
# 2        True   neutral
# 3        True   neutral
# 4        True   neutral
# 5        True   neutral
# 6        True   neutral
# 7        True   neutral
# 8        True   neutral
# 9        True  positive

# %% [markdown]
# ## Loading model and tokenizer

# %%
tokenizer = BertTokenizer.from_pretrained(r'models\tokenizer')
model = BertForSequenceClassification.from_pretrained(r'models\finetuned_finbert')

# %%
X = headlines['headline']
encodings = tokenizer(X.tolist(), truncation=True, padding=True)

# %% [markdown]
# ## Preparing dataset

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        item = {key : torch.tensor(val[idx]) for key, val in self.encodings.items()}
        return item
    
    def __len__(self):
        return len(self.encodings['input_ids'])

# %%
dataset = Dataset(encodings)

# %% [markdown]
# ## Predicting sentiments

# %%
def analyze_sentiment(dataset):
    model.eval()
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=8)

    predictions = []
    probabilities = []

    with torch.no_grad():
        for batch in tqdm(dataloader, desc='Sentiment Analysis', unit="batch"):
            input_ids = batch['input_ids']
            attention_mask = batch['attention_mask']

            with torch.no_grad():
                outputs = model(input_ids, attention_mask=attention_mask)
                logits = outputs.logits
                probabilities_batch = torch.softmax(logits, dim=1)
                predicted_labels_batch = torch.argmax(probabilities_batch, dim=1)
            
            predictions.extend(predicted_labels_batch.tolist())
            probabilities.extend(probabilities_batch.tolist())

    return predictions, probabilities

# %%
predicted, probabilities = analyze_sentiment(dataset)

# %%
# %store -r predicted

# %%
label_map = {0: 'negative', 1: 'neutral', 2: 'positive'}
predicted_sentiments = [label_map[label] for label in predicted]
data = {'headline': X.tolist(), 'sentiment': predicted_sentiments}
results = pd.DataFrame(data)

# %%
results
# Out:
#                                                 headline sentiment
# 0                          Hess Corp's Dividend Analysis   neutral
# 1                                                PepsiCo   neutral
# 2                          Analyst Report: Rollins, Inc.   neutral
# 3                         Analyst Report: Welltower Inc.   neutral
# 4                        Oracle Corp's Dividend Analysis   neutral
# ...                                                  ...       ...
# 14339  IBM stock nears an all-time highand it may hav...   neutral
# 14340           12 Best Alternatives to a 4-Year College   neutral
# 14341  Forget Meta Platforms: 2 Artificial Intelligen...   neutral
# 14342  IBM Eyes First Record Since 2013 as AI Optimis...  positive
# 14343  Caution! Why IBM Is a Riskier AI Play Than You...   neutral
#
# [14344 rows x 2 columns]

# %% [markdown]
# ## Updating sentiments for individual headlines

# %%
def update_headlines(rows):
    try:
        with conn.cursor() as curr:
            data = [(row['sentiment'], row['headline']) for _, row in rows.iterrows()]
            curr.executemany("UPDATE headlines SET sentiment = %s WHERE headline = %s", data)
        return True
    except Exception as e:
        print(f"Error updating headline: {e}")
        return False

# %%
with tqdm(total=len(results), desc="Updating headlines", unit="rows") as pbar:
    for _, row in results.iterrows():
        update_headlines(pd.DataFrame([row]).copy())
        pbar.update(1)
    
conn.commit()

# %% [markdown]
# ## Aggregating sentiments for stocks across multiple time periods

# %%
def extract_headlines():
    with conn.cursor() as curr:
        curr.execute("SELECT * FROM headlines")
        headlines = curr.fetchall()
        columns = [curr.description[i][0] for i in range(len(curr.description))]
        df = pd.DataFrame(headlines, columns=columns)
    return df

# %%
df = extract_headlines()
grouped = df.groupby(['ticker', 'is_daily', 'is_weekly', 'is_monthly'])

aggregated_sentiments = {}
for group, data in grouped:
    ticker, is_daily, is_weekly, is_monthly = group
    sentiment_counts = data['sentiment'].value_counts()
    predominant_sentiment = sentiment_counts.idxmax()
    aggregated_sentiments.setdefault(ticker, {})[(is_daily, is_weekly, is_monthly)] = predominant_sentiment

# %%
def aggregate_sentiments_by_company(headlines):
    aggregated_sentiments = {}

    for _, row in headlines.iterrows():
        ticker = row['ticker']

        if ticker not in aggregated_sentiments:
            aggregated_sentiments[ticker] = {}

        period = (row['is_daily'], row['is_weekly'], row['is_monthly'])
        sentiment = row['sentiment']

        aggregated_sentiments[ticker][period] = sentiment

    return aggregated_sentiments

# %%
def update_stocks_table(aggregated_sentiments):
    with conn.cursor() as cursor:
        for ticker, sentiments in aggregated_sentiments.items():
            daily_sentiment = sentiments.get((True, True, True), None)
            weekly_sentiment = sentiments.get((False, True, True), None)
            monthly_sentiment = sentiments.get((False, False, True), None)

            if daily_sentiment is None:
                daily_sentiment = weekly_sentiment if weekly_sentiment is not None else monthly_sentiment
            if weekly_sentiment is None:
                weekly_sentiment = monthly_sentiment if monthly_sentiment is not None else daily_sentiment
            if monthly_sentiment is None:
                monthly_sentiment = weekly_sentiment if weekly_sentiment is not None else daily_sentiment

            cursor.execute("UPDATE stocks SET daily_sentiment = %s, weekly_sentiment = %s, monthly_sentiment = %s WHERE ticker = %s",
                                (daily_sentiment, weekly_sentiment, monthly_sentiment, ticker))
            print(f"Updated sentiments for Ticker: {ticker}")
        
    conn.commit()
    print("Sentiments updated successfully.")

# %%
update_stocks_table(aggregated_sentiments)
# Out:
# Updated sentiments for Ticker: A
# Updated sentiments for Ticker: AAL
# Updated sentiments for Ticker: AAPL
# Updated sentiments for Ticker: ABBV
# Updated sentiments for Ticker: ABNB
# Updated sentiments for Ticker: ABT
# Updated sentiments for Ticker: ACGL
# Updated sentiments for Ticker: ACN
# Updated sentiments for Ticker: ADBE
# Updated sentiments for Ticker: ADI
# Updated sentiments for Ticker: ADM
# Updated sentiments for Ticker: ADP
# Updated sentiments for Ticker: ADSK
# Updated sentiments for Ticker: AEE
# Updated sentiments for Ticker: AEP
# Updated sentiments for Ticker: AES
# Updated sentiments for Ticker: AFL
# Updated sentiments for Ticker: AIG
# Updated sentiments for Ticker: AIZ
# Updated sentiments for Ticker: AJG
# Updated sentiments for Ticker: AKAM
# Updated sentiments for Ticker: ALB
# Updated sentiments for Ticker: ALGN
# Updated sentiments for Ticker: ALL
# Updated sentiments for Ticker: ALLE
# Updated sentiments for Ticker: AMAT
# Updated sentiments for Ticker: AMCR
# Updated sentiments for Ticker: AMD
# Updated sentiments for Ticker: AME
# Updated sentiments for Ticker: AMGN
# Updated sentiments for Ticker: AMP
# Updated sentiments for Ticker: AMT
# Updated sentiments for Ticker: AMZN
# Updated sentiments for Ticker: ANET
# Updated sentiments for Ticker: ANSS
# Updated sentiments for Ticker: AON
# Updated sentiments for Ticker: AOS
# Updated sentiments for Ticker: APA
# Updated sentiments for Ticker: APD
# Updated sentiments for Ticker: APH
# Updated sentiments for Ticker: APTV
# Updated sentiments for Ticker: ARE
# Updated sentiments for Ticker: ATO
# Updated sentiments for Ticker: AVB
# Updated sentiments for Ticker: AVGO
# Updated sentiments for Ticker: AVY
# Updated sentiments for Ticker: AWK
# Updated sentiments for Ticker: AXON
# Updated sentiments for Ticker: AXP
# Updated sentiments for Ticker: AZO
# Updated sentiments for Ticker: BA
# Updated sentiments for Ticker: BAC
# Updated sentiments for Ticker: BALL
# Updated sentiments for Ticker: BAX
# Updated sentiments for Ticker: BBWI
# Updated sentiments for Ticker: BBY
# Updated sentiments for Ticker: BDX
# Updated sentiments for Ticker: BEN
# Updated sentiments for Ticker: BF-B
# Updated sentiments for Ticker: BG
# Updated sentiments for Ticker: BIIB
# Updated sentiments for Ticker: BIO
# Updated sentiments for Ticker: BK
# Updated sentiments for Ticker: BKNG
# Updated sentiments for Ticker: BKR
# Updated sentiments for Ticker: BLDR
# Updated sentiments for Ticker: BLK
# Updated sentiments for Ticker: BMY
# Updated sentiments for Ticker: BR
# Updated sentiments for Ticker: BRK-B
# Updated sentiments for Ticker: BRO
# Updated sentiments for Ticker: BSX
# Updated sentiments for Ticker: BWA
# Updated sentiments for Ticker: BX
# Updated sentiments for Ticker: BXP
# Updated sentiments for Ticker: C
# Updated sentiments for Ticker: CAG
# Updated sentiments for Ticker: CAH
# Updated sentiments for Ticker: CARR
# Updated sentiments for Ticker: CAT
# Updated sentiments for Ticker: CB
# Updated sentiments for Ticker: CBOE
# Updated sentiments for Ticker: CBRE
# Updated sentiments for Ticker: CCI
# Updated sentiments for Ticker: CCL
# Updated sentiments for Ticker: CDNS
# Updated sentiments for Ticker: CDW
# Updated sentiments for Ticker: CE
# Updated sentiments for Ticker: CEG
# Updated sentiments for Ticker: CF
# Updated sentiments for Ticker: CFG
# Updated sentiments for Ticker: CHD
# Updated sentiments for Ticker: CHRW
# Updated sentiments for Ticker: CHTR
# Updated sentiments for Ticker: CI
# Updated sentiments for Ticker: CINF
# Updated sentiments for Ticker: CL
# Updated sentiments for Ticker: CLX
# Updated sentiments for Ticker: CMA
# Updated sentiments for Ticker: CMCSA
# Updated sentiments for Ticker: CME
# Updated sentiments for Ticker: CMG
# Updated sentiments for Ticker: CMI
# Updated sentiments for Ticker: CMS
# Updated sentiments for Ticker: CNC
# Updated sentiments for Ticker: CNP
# Updated sentiments for Ticker: COF
# Updated sentiments for Ticker: COO
# Updated sentiments for Ticker: COP
# Updated sentiments for Ticker: COR
# Updated sentiments for Ticker: COST
# Updated sentiments for Ticker: CPAY
# Updated sentiments for Ticker: CPB
# Updated sentiments for Ticker: CPRT
# Updated sentiments for Ticker: CPT
# Updated sentiments for Ticker: CRL
# Updated sentiments for Ticker: CRM
# Updated sentiments for Ticker: CSCO
# Updated sentiments for Ticker: CSGP
# Updated sentiments for Ticker: CSX
# Updated sentiments for Ticker: CTAS
# Updated sentiments for Ticker: CTLT
# Updated sentiments for Ticker: CTRA
# Updated sentiments for Ticker: CTSH
# Updated sentiments for Ticker: CTVA
# Updated sentiments for Ticker: CVS
# Updated sentiments for Ticker: CVX
# Updated sentiments for Ticker: CZR
# Updated sentiments for Ticker: D
# Updated sentiments for Ticker: DAL
# Updated sentiments for Ticker: DAY
# Updated sentiments for Ticker: DD
# Updated sentiments for Ticker: DE
# Updated sentiments for Ticker: DECK
# Updated sentiments for Ticker: DFS
# Updated sentiments for Ticker: DG
# Updated sentiments for Ticker: DGX
# Updated sentiments for Ticker: DHI
# Updated sentiments for Ticker: DHR
# Updated sentiments for Ticker: DIS
# Updated sentiments for Ticker: DLR
# Updated sentiments for Ticker: DLTR
# Updated sentiments for Ticker: DOC
# Updated sentiments for Ticker: DOV
# Updated sentiments for Ticker: DOW
# Updated sentiments for Ticker: DPZ
# Updated sentiments for Ticker: DRI
# Updated sentiments for Ticker: DTE
# Updated sentiments for Ticker: DUK
# Updated sentiments for Ticker: DVA
# Updated sentiments for Ticker: DVN
# Updated sentiments for Ticker: DXCM
# Updated sentiments for Ticker: EA
# Updated sentiments for Ticker: EBAY
# Updated sentiments for Ticker: ECL
# Updated sentiments for Ticker: ED
# Updated sentiments for Ticker: EFX
# Updated sentiments for Ticker: EG
# Updated sentiments for Ticker: EIX
# Updated sentiments for Ticker: EL
# Updated sentiments for Ticker: ELV
# Updated sentiments for Ticker: EMN
# Updated sentiments for Ticker: EMR
# Updated sentiments for Ticker: ENPH
# Updated sentiments for Ticker: EOG
# Updated sentiments for Ticker: EPAM
# Updated sentiments for Ticker: EQIX
# Updated sentiments for Ticker: EQR
# Updated sentiments for Ticker: EQT
# Updated sentiments for Ticker: ES
# Updated sentiments for Ticker: ESS
# Updated sentiments for Ticker: ETN
# Updated sentiments for Ticker: ETR
# Updated sentiments for Ticker: ETSY
# Updated sentiments for Ticker: EVRG
# Updated sentiments for Ticker: EW
# Updated sentiments for Ticker: EXC
# Updated sentiments for Ticker: EXPD
# Updated sentiments for Ticker: EXPE
# Updated sentiments for Ticker: EXR
# Updated sentiments for Ticker: F
# Updated sentiments for Ticker: FANG
# Updated sentiments for Ticker: FAST
# Updated sentiments for Ticker: FCX
# Updated sentiments for Ticker: FDS
# Updated sentiments for Ticker: FDX
# Updated sentiments for Ticker: FE
# Updated sentiments for Ticker: FFIV
# Updated sentiments for Ticker: FI
# Updated sentiments for Ticker: FICO
# Updated sentiments for Ticker: FIS
# Updated sentiments for Ticker: FITB
# Updated sentiments for Ticker: FMC
# Updated sentiments for Ticker: FOX
# Updated sentiments for Ticker: FOXA
# Updated sentiments for Ticker: FRT
# Updated sentiments for Ticker: FSLR
# Updated sentiments for Ticker: FTNT
# Updated sentiments for Ticker: FTV
# Updated sentiments for Ticker: GD
# Updated sentiments for Ticker: GE
# Updated sentiments for Ticker: GEHC
# Updated sentiments for Ticker: GEN
# Updated sentiments for Ticker: GEV
# Updated sentiments for Ticker: GILD
# Updated sentiments for Ticker: GIS
# Updated sentiments for Ticker: GL
# Updated sentiments for Ticker: GLW
# Updated sentiments for Ticker: GM
# Updated sentiments for Ticker: GNRC
# Updated sentiments for Ticker: GOOG
# Updated sentiments for Ticker: GOOGL
# Updated sentiments for Ticker: GPC
# Updated sentiments for Ticker: GPN
# Updated sentiments for Ticker: GRMN
# Updated sentiments for Ticker: GS
# Updated sentiments for Ticker: GWW
# Updated sentiments for Ticker: HAL
# Updated sentiments for Ticker: HAS
# Updated sentiments for Ticker: HBAN
# Updated sentiments for Ticker: HCA
# Updated sentiments for Ticker: HD
# Updated sentiments for Ticker: HES
# Updated sentiments for Ticker: HIG
# Updated sentiments for Ticker: HII
# Updated sentiments for Ticker: HLT
# Updated sentiments for Ticker: HOLX
# Updated sentiments for Ticker: HON
# Updated sentiments for Ticker: HPE
# Updated sentiments for Ticker: HPQ
# Updated sentiments for Ticker: HRL
# Updated sentiments for Ticker: HSIC
# Updated sentiments for Ticker: HST
# Updated sentiments for Ticker: HSY
# Updated sentiments for Ticker: HUBB
# Updated sentiments for Ticker: HUM
# Updated sentiments for Ticker: HWM
# Updated sentiments for Ticker: IBM
# Updated sentiments for Ticker: ICE
# Updated sentiments for Ticker: IDXX
# Updated sentiments for Ticker: IEX
# Updated sentiments for Ticker: IFF
# Updated sentiments for Ticker: ILMN
# Updated sentiments for Ticker: INCY
# Updated sentiments for Ticker: INTC
# Updated sentiments for Ticker: INTU
# Updated sentiments for Ticker: INVH
# Updated sentiments for Ticker: IP
# Updated sentiments for Ticker: IPG
# Updated sentiments for Ticker: IQV
# Updated sentiments for Ticker: IR
# Updated sentiments for Ticker: IRM
# Updated sentiments for Ticker: ISRG
# Updated sentiments for Ticker: IT
# Updated sentiments for Ticker: ITW
# Updated sentiments for Ticker: IVZ
# Updated sentiments for Ticker: J
# Updated sentiments for Ticker: JBHT
# Updated sentiments for Ticker: JBL
# Updated sentiments for Ticker: JCI
# Updated sentiments for Ticker: JKHY
# Updated sentiments for Ticker: JNJ
# Updated sentiments for Ticker: JNPR
# Updated sentiments for Ticker: JPM
# Updated sentiments for Ticker: K
# Updated sentiments for Ticker: KDP
# Updated sentiments for Ticker: KEY
# Updated sentiments for Ticker: KEYS
# Updated sentiments for Ticker: KHC
# Updated sentiments for Ticker: KIM
# Updated sentiments for Ticker: KLAC
# Updated sentiments for Ticker: KMB
# Updated sentiments for Ticker: KMI
# Updated sentiments for Ticker: KMX
# Updated sentiments for Ticker: KO
# Updated sentiments for Ticker: KR
# Updated sentiments for Ticker: KVUE
# Updated sentiments for Ticker: LDOS
# Updated sentiments for Ticker: LEN
# Updated sentiments for Ticker: LH
# Updated sentiments for Ticker: LHX
# Updated sentiments for Ticker: LIN
# Updated sentiments for Ticker: LKQ
# Updated sentiments for Ticker: LLY
# Updated sentiments for Ticker: LMT
# Updated sentiments for Ticker: LNT
# Updated sentiments for Ticker: LOW
# Updated sentiments for Ticker: LRCX
# Updated sentiments for Ticker: LULU
# Updated sentiments for Ticker: LUV
# Updated sentiments for Ticker: LVS
# Updated sentiments for Ticker: LW
# Updated sentiments for Ticker: LYB
# Updated sentiments for Ticker: LYV
# Updated sentiments for Ticker: MA
# Updated sentiments for Ticker: MAA
# Updated sentiments for Ticker: MAR
# Updated sentiments for Ticker: MAS
# Updated sentiments for Ticker: MCD
# Updated sentiments for Ticker: MCHP
# Updated sentiments for Ticker: MCK
# Updated sentiments for Ticker: MCO
# Updated sentiments for Ticker: MDLZ
# Updated sentiments for Ticker: MDT
# Updated sentiments for Ticker: MET
# Updated sentiments for Ticker: META
# Updated sentiments for Ticker: MGM
# Updated sentiments for Ticker: MHK
# Updated sentiments for Ticker: MKC
# Updated sentiments for Ticker: MKTX
# Updated sentiments for Ticker: MLM
# Updated sentiments for Ticker: MMC
# Updated sentiments for Ticker: MMM
# Updated sentiments for Ticker: MNST
# Updated sentiments for Ticker: MO
# Updated sentiments for Ticker: MOH
# Updated sentiments for Ticker: MOS
# Updated sentiments for Ticker: MPC
# Updated sentiments for Ticker: MPWR
# Updated sentiments for Ticker: MRK
# Updated sentiments for Ticker: MRNA
# Updated sentiments for Ticker: MRO
# Updated sentiments for Ticker: MS
# Updated sentiments for Ticker: MSCI
# Updated sentiments for Ticker: MSFT
# Updated sentiments for Ticker: MSI
# Updated sentiments for Ticker: MTB
# Updated sentiments for Ticker: MTCH
# Updated sentiments for Ticker: MTD
# Updated sentiments for Ticker: MU
# Updated sentiments for Ticker: NCLH
# Updated sentiments for Ticker: NDAQ
# Updated sentiments for Ticker: NDSN
# Updated sentiments for Ticker: NEE
# Updated sentiments for Ticker: NEM
# Updated sentiments for Ticker: NFLX
# Updated sentiments for Ticker: NI
# Updated sentiments for Ticker: NKE
# Updated sentiments for Ticker: NOC
# Updated sentiments for Ticker: NOW
# Updated sentiments for Ticker: NRG
# Updated sentiments for Ticker: NSC
# Updated sentiments for Ticker: NTAP
# Updated sentiments for Ticker: NTRS
# Updated sentiments for Ticker: NUE
# Updated sentiments for Ticker: NVDA
# Updated sentiments for Ticker: NVR
# Updated sentiments for Ticker: NWS
# Updated sentiments for Ticker: NWSA
# Updated sentiments for Ticker: NXPI
# Updated sentiments for Ticker: O
# Updated sentiments for Ticker: ODFL
# Updated sentiments for Ticker: OKE
# Updated sentiments for Ticker: OMC
# Updated sentiments for Ticker: ON
# Updated sentiments for Ticker: ORCL
# Updated sentiments for Ticker: ORLY
# Updated sentiments for Ticker: OTIS
# Updated sentiments for Ticker: OXY
# Updated sentiments for Ticker: PANW
# Updated sentiments for Ticker: PARA
# Updated sentiments for Ticker: PAYC
# Updated sentiments for Ticker: PAYX
# Updated sentiments for Ticker: PCAR
# Updated sentiments for Ticker: PCG
# Updated sentiments for Ticker: PEG
# Updated sentiments for Ticker: PEP
# Updated sentiments for Ticker: PFE
# Updated sentiments for Ticker: PFG
# Updated sentiments for Ticker: PG
# Updated sentiments for Ticker: PGR
# Updated sentiments for Ticker: PH
# Updated sentiments for Ticker: PHM
# Updated sentiments for Ticker: PKG
# Updated sentiments for Ticker: PLD
# Updated sentiments for Ticker: PM
# Updated sentiments for Ticker: PNC
# Updated sentiments for Ticker: PNR
# Updated sentiments for Ticker: PNW
# Updated sentiments for Ticker: PODD
# Updated sentiments for Ticker: POOL
# Updated sentiments for Ticker: PPG
# Updated sentiments for Ticker: PPL
# Updated sentiments for Ticker: PRU
# Updated sentiments for Ticker: PSA
# Updated sentiments for Ticker: PSX
# Updated sentiments for Ticker: PTC
# Updated sentiments for Ticker: PWR
# Updated sentiments for Ticker: PXD
# Updated sentiments for Ticker: PYPL
# Updated sentiments for Ticker: QCOM
# Updated sentiments for Ticker: QRVO
# Updated sentiments for Ticker: RCL
# Updated sentiments for Ticker: REG
# Updated sentiments for Ticker: REGN
# Updated sentiments for Ticker: RF
# Updated sentiments for Ticker: RHI
# Updated sentiments for Ticker: RJF
# Updated sentiments for Ticker: RL
# Updated sentiments for Ticker: RMD
# Updated sentiments for Ticker: ROK
# Updated sentiments for Ticker: ROL
# Updated sentiments for Ticker: ROP
# Updated sentiments for Ticker: ROST
# Updated sentiments for Ticker: RSG
# Updated sentiments for Ticker: RTX
# Updated sentiments for Ticker: RVTY
# Updated sentiments for Ticker: SBAC
# Updated sentiments for Ticker: SBUX
# Updated sentiments for Ticker: SCHW
# Updated sentiments for Ticker: SHW
# Updated sentiments for Ticker: SJM
# Updated sentiments for Ticker: SLB
# Updated sentiments for Ticker: SMCI
# Updated sentiments for Ticker: SNA
# Updated sentiments for Ticker: SNPS
# Updated sentiments for Ticker: SO
# Updated sentiments for Ticker: SOLV
# Updated sentiments for Ticker: SPG
# Updated sentiments for Ticker: SPGI
# Updated sentiments for Ticker: SRE
# Updated sentiments for Ticker: STE
# Updated sentiments for Ticker: STLD
# Updated sentiments for Ticker: STT
# Updated sentiments for Ticker: STX
# Updated sentiments for Ticker: STZ
# Updated sentiments for Ticker: SWK
# Updated sentiments for Ticker: SWKS
# Updated sentiments for Ticker: SYF
# Updated sentiments for Ticker: SYK
# Updated sentiments for Ticker: SYY
# Updated sentiments for Ticker: T
# Updated sentiments for Ticker: TAP
# Updated sentiments for Ticker: TDG
# Updated sentiments for Ticker: TDY
# Updated sentiments for Ticker: TECH
# Updated sentiments for Ticker: TEL
# Updated sentiments for Ticker: TER
# Updated sentiments for Ticker: TFC
# Updated sentiments for Ticker: TFX
# Updated sentiments for Ticker: TGT
# Updated sentiments for Ticker: TJX
# Updated sentiments for Ticker: TMO
# Updated sentiments for Ticker: TMUS
# Updated sentiments for Ticker: TPR
# Updated sentiments for Ticker: TRGP
# Updated sentiments for Ticker: TRMB
# Updated sentiments for Ticker: TROW
# Updated sentiments for Ticker: TRV
# Updated sentiments for Ticker: TSCO
# Updated sentiments for Ticker: TSLA
# Updated sentiments for Ticker: TSN
# Updated sentiments for Ticker: TT
# Updated sentiments for Ticker: TTWO
# Updated sentiments for Ticker: TXN
# Updated sentiments for Ticker: TXT
# Updated sentiments for Ticker: TYL
# Updated sentiments for Ticker: UAL
# Updated sentiments for Ticker: UBER
# Updated sentiments for Ticker: UDR
# Updated sentiments for Ticker: UHS
# Updated sentiments for Ticker: ULTA
# Updated sentiments for Ticker: UNH
# Updated sentiments for Ticker: UNP
# Updated sentiments for Ticker: UPS
# Updated sentiments for Ticker: URI
# Updated sentiments for Ticker: USB
# Updated sentiments for Ticker: V
# Updated sentiments for Ticker: VICI
# Updated sentiments for Ticker: VLO
# Updated sentiments for Ticker: VLTO
# Updated sentiments for Ticker: VMC
# Updated sentiments for Ticker: VRSK
# Updated sentiments for Ticker: VRSN
# Updated sentiments for Ticker: VRTX
# Updated sentiments for Ticker: VTR
# Updated sentiments for Ticker: VTRS
# Updated sentiments for Ticker: VZ
# Updated sentiments for Ticker: WAB
# Updated sentiments for Ticker: WAT
# Updated sentiments for Ticker: WBA
# Updated sentiments for Ticker: WBD
# Updated sentiments for Ticker: WDC
# Updated sentiments for Ticker: WEC
# Updated sentiments for Ticker: WELL
# Updated sentiments for Ticker: WFC
# Updated sentiments for Ticker: WM
# Updated sentiments for Ticker: WMB
# Updated sentiments for Ticker: WMT
# Updated sentiments for Ticker: WRB
# Updated sentiments for Ticker: WRK
# Updated sentiments for Ticker: WST
# Updated sentiments for Ticker: WTW
# Updated sentiments for Ticker: WY
# Updated sentiments for Ticker: WYNN
# Updated sentiments for Ticker: XEL
# Updated sentiments for Ticker: XOM
# Updated sentiments for Ticker: XYL
# Updated sentiments for Ticker: YUM
# Updated sentiments for Ticker: ZBH
# Updated sentiments for Ticker: ZBRA
# Updated sentiments for Ticker: ZTS
# Sentiments updated successfully.
